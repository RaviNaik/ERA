# %%
# !git clone https://github.com/GunaKoppula/ERAV1-Session-15
# !git pull
# %cd ERAV1-Session-15
# Out:
# Cloning into 'ERAV1-Session-15'...
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 13 (delta 2), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (13/13), 9.61 KiB | 9.61 MiB/s, done.
# Resolving deltas: 100% (2/2), done.
# /content/ERAV1-Session-15

# %%
from config import get_config
cfg = get_config()
cfg['batch_size'] = 6
cfg['preload'] = None
cfg['num_epochs'] = 10

from train import train_model
train_model(cfg)
# Out:
# Using device: cuda
# ...
# Generating train split:   0%|          | 0/32332 [00:00<?, ? examples/s]
# Max length of source sentence: 309
# Max length of target sentence: 274
# Processing Epoch 00: 100%|██████████| 4850/4850 [26:23<00:00,  3.06it/s, loss=6.348]
# --------------------------------------------------------------------------------
#     SOURCE: The High Street stunk of oil; we wondered how people could live in it.
#     TARGET: Il corso puzzava di petrolio; e ci domandammo come la popolazione potesse viverci.
#  PREDICTED: Il signor Rochester era un ’ altra vita , ma non si .
# --------------------------------------------------------------------------------
#     SOURCE: Of course his misfortune...'
#     TARGET: S’intende, la sua sventura...
#  PREDICTED: E non si .
# --------------------------------------------------------------------------------
# ...
