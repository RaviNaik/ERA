# %% [markdown]
# # Session 9 — The Loss Harness: Making Next-Token Cross-Entropy Correct and Observable
#
# **Starting point:**
#
# ```python
# hidden = model(tokens)
# logits = output_head(hidden)
# loss = cross_entropy(
#     logits[:, :-1].reshape(-1, vocab_size),
#     tokens[:, 1:].reshape(-1),
# )
# ```
#
# This notebook takes that four-line snippet and makes it **correct and observable**:
# every tensor shape is printed and explained, the input/target shift is verified by
# reading actual token *strings* (not ids), padding and document boundaries are
# explicitly masked with the contributing-token count shown to change, perplexity is
# checked against the vocabulary size as a sanity anchor, tied vs. untied head
# parameter counts are compared, and peak memory is measured for an ordinary vs. a
# hand-written chunked cross-entropy.
#
# Part 2 adds a second output head that predicts `t+2`, trains it jointly with a
# `t+1` head on the same shared trunk, and compares how the two losses evolve.
#
# **Stack:** a `uv`-managed project, a decoder-only transformer (~50M-parameter
# trunk: `d_model=512`, 8 layers, 8 heads) trained from scratch, **WikiText-103-raw**
# (~117M tokens) tokenized with the real GPT-2 BPE vocabulary (50,257 tokens), and
# [Aim](https://aimstack.io/) for tracking every run's params, metrics, and logs.
#
# > **Two run scales.** The defaults below are the *decent proxy scale* meant for a
# > GPU server. Setting the environment variable `S9_SMOKE=1` before launching
# > shrinks the model, dataset, and step count so the whole notebook runs
# > top-to-bottom on a CPU or a tiny GPU in a couple of minutes — that is what
# > `dry_run.py` uses to verify the notebook executes end-to-end before the real run.
#
# > The one rule this notebook takes seriously: **a target shift in the wrong
# > direction can produce a beautiful loss curve.** Every claim below is checked by
# > printing the actual numbers and strings involved, not by trusting that the code
# > "looks right."

# %% [markdown]
# ## 0. Setup & Environment
#
# Standard library, PyTorch, and this project's own `src/harness` package (the model,
# data, and loss-harness utilities). `RESULTS` is a running dict we fill in as we go —
# it becomes the final "seven numbers" summary at the end of the notebook.

# %%
import sys, os, time, math, json

sys.path.insert(0, os.path.abspath("src"))

import numpy as np
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt
import pandas as pd

from harness.model import ModelConfig, TinyGPT, OutputHead, count_parameters
from harness.data import (
    get_tokenizer,
    load_and_tokenize,
    pack_documents,
    make_batches,
    build_padded_batch,
    EOT_ID,
)
from harness.losses import (
    ordinary_cross_entropy,
    chunked_cross_entropy,
    chunked_cross_entropy_backward,
    perplexity,
    measure_peak_memory_bytes,
)
from harness.utils import (
    set_seed,
    get_device,
    describe_shape,
    human_bytes,
    collect_params,
)

set_seed(1337)
DEVICE = get_device()
RESULTS = {}  # accumulates the headline numbers for the final summary

# ---------------------------------------------------------------------------
# Run configuration. Two scales, selected by the S9_SMOKE environment variable.
#   S9_SMOKE unset / "0"  -> decent proxy scale, for a GPU server
#   S9_SMOKE = "1"         -> tiny smoke scale, runs on CPU in ~2 min (dry_run.py)
# Only the scale changes; every check, mask, and measurement below is identical.
# ---------------------------------------------------------------------------
SMOKE = os.environ.get("S9_SMOKE", "0") == "1"

if SMOKE:
    DATASET_CONFIG = "wikitext-2-raw-v1"
    MAX_DOCS = 4000
    D_MODEL, N_LAYERS, N_HEADS, MAX_SEQ_LEN = 128, 2, 2, 256
    SEQ_LEN, BATCH_SIZE, N_STEPS = 64, 8, 20
    MEM_N_TOKENS, MEM_CHUNK = 4096, 512
else:
    DATASET_CONFIG = "wikitext-103-raw-v1"
    MAX_DOCS = None
    D_MODEL, N_LAYERS, N_HEADS, MAX_SEQ_LEN = 512, 8, 8, 512
    # batch 12 x seq 512 keeps the two full [B*T, V] logits tensors (one per head)
    # within ~5 GB in fp32; raise BATCH_SIZE if the GPU server has room.
    SEQ_LEN, BATCH_SIZE, N_STEPS = 512, 12, 4000
    # §3.7: N=32,768 tokens (= batch 64 x seq 512, flattened). Large enough that the
    # ordinary [N, V] path is a ~12 GiB wall (logits + fp32 log-softmax + gradient),
    # small enough to stay well within a 24-48 GiB GPU. The byte-accounting printed
    # in that cell reconciles measured-vs-theoretical for both paths.
    MEM_N_TOKENS, MEM_CHUNK = 32768, 2048

print(f"run scale              : {'SMOKE' if SMOKE else 'FULL (decent proxy scale)'}")
print(f"dataset config         : {DATASET_CONFIG}")
print(
    f"model                  : d_model={D_MODEL} n_layers={N_LAYERS} n_heads={N_HEADS} max_seq_len={MAX_SEQ_LEN}"
)
print(
    f"training               : seq_len={SEQ_LEN} batch_size={BATCH_SIZE} n_steps={N_STEPS}"
)

# A small, fixed categorical palette used for every chart in this notebook:
# blue for the t+1 head, amber for the t+2 head, gray for derived/sum series.
# Chosen for light/dark legibility and blue/amber colorblind-safe separation.
COLORS = dict(head1="#2563EB", head2="#F59E0B", sum="#6B7280", grid="#E5E7EB")
plt.rcParams.update(
    {
        "figure.facecolor": "white",
        "axes.facecolor": "white",
        "axes.edgecolor": "#9CA3AF",
        "axes.grid": True,
        "grid.color": COLORS["grid"],
        "grid.linewidth": 0.8,
        "font.size": 11,
    }
)
os.makedirs("assets", exist_ok=True)

print("=" * 70)
print("ENVIRONMENT")
print("=" * 70)
print(f"torch version        : {torch.__version__}")
print(f"cuda available        : {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"gpu                    : {torch.cuda.get_device_name(0)}")
    print(
        f"total gpu memory       : {human_bytes(torch.cuda.get_device_properties(0).total_memory)}"
    )
print(f"device in use          : {DEVICE}")
print(f"numpy version          : {np.__version__}")
# Out:
# run scale              : FULL (decent proxy scale)
# dataset config         : wikitext-103-raw-v1
# model                  : d_model=512 n_layers=8 n_heads=8 max_seq_len=512
# training               : seq_len=512 batch_size=12 n_steps=4000
# ======================================================================
# ENVIRONMENT
# ======================================================================
# torch version        : 2.6.0+cu124
# cuda available        : True
# gpu                    : NVIDIA RTX A6000
# total gpu memory       : 47.54 GiB
# device in use          : cuda
# numpy version          : 2.4.6

# %% [markdown]
# ## 1. Dataset & Tokenizer
#
# **Dataset:** [WikiText-103](https://huggingface.co/datasets/Salesforce/wikitext)
# (raw) at full scale (~117M GPT-2 tokens), or WikiText-2 (~2M tokens) under
# `S9_SMOKE=1`. Both are genuine Wikipedia prose with real document/section
# boundaries, so the padding, packing, and shift checks below are checking something
# real rather than a synthetic toy. Tokenized ids are cached under `.cache/` so
# re-running the notebook skips re-encoding.
#
# **Tokenizer:** GPT-2's BPE encoding via `tiktoken` — a real sub-word vocabulary of
# **50,257 tokens**. This matters for the "print the actual strings" check: with a
# real BPE tokenizer, misalignment is visually obvious (you'll see whole sub-words
# shifted by one position), which a toy char-level vocabulary would hide.

# %%
print(f"Loading {DATASET_CONFIG} and tokenizing with GPT-2 BPE (tiktoken)...")
enc = get_tokenizer()
VOCAB_SIZE = enc.n_vocab
print(f"tokenizer            : gpt2 (tiktoken)")
print(f"vocab_size (V)        : {VOCAB_SIZE:,}")

t0 = time.time()
train_docs = load_and_tokenize(split="train", config=DATASET_CONFIG, max_docs=MAX_DOCS)
print(f"\nloaded {len(train_docs):,} documents in {time.time() - t0:.1f}s")

total_tokens = sum(len(d) for d in train_docs)
print(f"total tokens           : {total_tokens:,}")
print(f"avg tokens / doc        : {total_tokens / len(train_docs):.1f}")
print(
    f"shortest / longest doc  : {min(len(d) for d in train_docs)} / {max(len(d) for d in train_docs)}"
)

print("\nSample document, decoded back to text (round-trip check that the")
print("tokenizer + dataset pipeline is sane):")
sample = train_docs[10][:30]
print(f"  ids  : {sample}")
print(f"  text : {enc.decode(sample)!r}")

RESULTS["vocab_size"] = VOCAB_SIZE
RESULTS["num_docs"] = len(train_docs)
RESULTS["total_tokens"] = total_tokens
# Out:
# Loading wikitext-103-raw-v1 and tokenizing with GPT-2 BPE (tiktoken)...
# tokenizer            : gpt2 (tiktoken)
# vocab_size (V)        : 50,257
#
# loaded 1,153,246 documents in 244.5s
# total tokens           : 115,689,651
# avg tokens / doc        : 100.3
# shortest / longest doc  : 4 / 1579
#
# Sample document, decoded back to text (round-trip check that the
# tokenizer + dataset pipeline is sane):
#   ids  : [1722, 262, 17871, 5321, 8720, 466, 407, 2152, 837, 262, 6727, 304, 29232, 684, 286, 262, 7096, 666, 5407, 14561, 262, 3721, 286, 19756, 2853, 12455, 287, 1502, 284, 3758]
#   text : 'As the Nameless officially do not exist , the upper echelons of the Gallian Army exploit the concept of plausible deniability in order to send'

# %% [markdown]
# ## 2. Model
#
# A decoder-only transformer: RMSNorm, pre-norm residual stream, a SwiGLU FFN, and
# ordinary causal multi-head self-attention. At the full scale this is a ~50M-param
# trunk (`d_model=512`, 8 layers) — a real proxy-scale model, not a toy — while the
# assignment's focus stays on the harness around the model.
#
# Critically, **the trunk returns hidden states only.** `TinyGPT.forward` never
# touches the vocabulary. The output head is a separate module attached afterward,
# exactly as in the assignment's harness (`hidden = model(tokens); logits =
# output_head(hidden)`), which is what lets us swap tied/untied heads and add a
# second head in Part 2 without touching the trunk at all.

# %%
cfg = ModelConfig(
    vocab_size=VOCAB_SIZE,
    d_model=D_MODEL,
    n_layers=N_LAYERS,
    n_heads=N_HEADS,
    max_seq_len=MAX_SEQ_LEN,
)

model = TinyGPT(cfg).to(DEVICE)
head = OutputHead(cfg.vocab_size, cfg.d_model, tied_weight=model.tok_emb.weight).to(
    DEVICE
)

trunk_params = count_parameters(model)
head_params_tied = head.num_parameters()

print("Model configuration:")
print(f"  d_model    = {cfg.d_model}")
print(f"  n_layers   = {cfg.n_layers}")
print(f"  n_heads    = {cfg.n_heads}")
print(
    f"  d_ff       = {cfg.d_ff}   (SwiGLU, derived so 3 matrices cost ~= a plain 4x two-matrix FFN)"
)
print(f"  max_seq_len= {cfg.max_seq_len}")
print(f"  vocab_size = {cfg.vocab_size:,}")
print()
print(f"trunk parameters (embeddings + blocks + norms)  : {trunk_params:,}")
print(
    f"  of which tok_emb table [V, D]                  : {model.tok_emb.weight.numel():,}"
)
print(
    f"output head parameters (tied -> reuses tok_emb)  : {head_params_tied:,} (0 NEW parameters)"
)
# Out:
# Model configuration:
#   d_model    = 512
#   n_layers   = 8
#   n_heads    = 8
#   d_ff       = 1408   (SwiGLU, derived so 3 matrices cost ~= a plain 4x two-matrix FFN)
#   max_seq_len= 512
#   vocab_size = 50,257
#
# trunk parameters (embeddings + blocks + norms)  : 51,692,544
#   of which tok_emb table [V, D]                  : 25,731,584
# output head parameters (tied -> reuses tok_emb)  : 25,731,584 (0 NEW parameters)

# %% [markdown]
# ## 3. Part 1 — The Loss Harness
#
# Working through the assignment's checklist, in order. Each subsection prints the
# evidence for its own claim rather than asserting it.

# %% [markdown]
# ### 3.1 Tensor Shapes — Every Dimension, Named
#
# `hidden = model(tokens)` then `logits = output_head(hidden)`. Below, every tensor's
# shape is printed with a one-line explanation of what each dimension actually
# indexes.

# %%
B, T = 4, 32
long_docs = [
    d for d in train_docs if len(d) >= T
]  # documents are different lengths; need >= T tokens each
tokens = torch.stack([torch.tensor(d[:T], dtype=torch.long) for d in long_docs[:B]]).to(
    DEVICE
)

print("Running the harness forward pass:\n")
hidden = model(tokens)
logits = head(hidden)

describe_shape(
    "tokens",
    tokens,
    [
        "batch: which example in the batch",
        "sequence position: which token in the context window",
    ],
)
print()
describe_shape(
    "hidden",
    hidden,
    [
        "batch: same batch axis as tokens",
        "sequence position: one hidden vector per input position",
        "hidden width D: the model's internal representation size (d_model)",
    ],
)
print()
describe_shape(
    "logits",
    logits,
    [
        "batch: same batch axis as tokens",
        "sequence position: one prediction per input position",
        "vocabulary V: one raw, unnormalized score per possible next token",
    ],
)

RESULTS["shapes"] = {
    "tokens": list(tokens.shape),
    "hidden": list(hidden.shape),
    "logits": list(logits.shape),
}
# Out:
# Running the harness forward pass:
#
# tokens: shape = (4, 32)  dtype = torch.int64
#     dim 0 (size      4): batch: which example in the batch
#     dim 1 (size     32): sequence position: which token in the context window
#
# hidden: shape = (4, 32, 512)  dtype = torch.float32
#     dim 0 (size      4): batch: same batch axis as tokens
#     dim 1 (size     32): sequence position: one hidden vector per input position
#     dim 2 (size    512): hidden width D: the model's internal representation size (d_model)
#
# logits: shape = (4, 32, 50257)  dtype = torch.float32
#     dim 0 (size      4): batch: same batch axis as tokens
#     dim 1 (size     32): sequence position: one prediction per input position
#     dim 2 (size  50257): vocabulary V: one raw, unnormalized score per possible next token

# %% [markdown]
# ### 3.2 Verify the Shift — Print the Strings, Not the IDs
#
# The whole trick of language modelling is that position `i`'s target is position
# `i+1`'s token: `logits[:, :-1]` (drop the last position — nothing follows it)
# against `tokens[:, 1:]` (drop the first position — nothing predicts it). An
# off-by-one here hands the model the answer and produces a beautiful, wrong loss
# curve. The only real defense is reading the actual decoded strings.
#
# **What this check does and doesn't do.** The printed table is for *human* reading —
# you look at it and confirm each target is genuinely the next word. The
# `mismatches` counter underneath only checks that `targets_out` equals `tokens[:, 1:]`,
# which is true by construction of the slice; it catches a wrong slice expression but
# it is *not* a mechanical proof that the loss call is aligned. That the model's
# `logits[:, :-1]` line up with these targets is a *functional* fact — it shows up as
# the perplexity anchor in **3.5** (an untrained model landing at ≈ `ln V`). Shift the
# wrong way and that anchor collapses well below `ln V`; forget to shift and an
# untrained model looks fine but the trained loss falls to near zero. The strings and
# the anchor together are the real guard.

# %%
tokens_in = tokens[:, :-1]
targets_out = tokens[:, 1:]

print(
    f"tokens_in   shape: {tuple(tokens_in.shape)}  (dropped LAST position: nothing follows it)"
)
print(
    f"targets_out shape: {tuple(targets_out.shape)}  (dropped FIRST position: nothing predicts it)"
)

print("\nInputs vs. targets, decoded to strings, example 0, first 12 positions:")
print(f"{'pos':>4} | {'input token':<18} | {'target token':<18} | check")
print("-" * 60)
n_mismatches = 0
for i in range(12):
    in_tok = enc.decode([tokens_in[0, i].item()])
    tgt_tok = enc.decode([targets_out[0, i].item()])
    expected_tgt = enc.decode([tokens[0, i + 1].item()])
    ok = tgt_tok == expected_tgt
    n_mismatches += not ok
    print(f"{i:>4} | {in_tok!r:<18} | {tgt_tok!r:<18} | {'OK' if ok else 'MISMATCH'}")

print(
    f"\ntarget-slice check: targets_out matches tokens[:, 1:] at {12 - n_mismatches}/12 positions "
    f"-> the target tensor is the correct slice."
)
print("(This confirms the slice only. That logits[:, :-1] is aligned to it in the loss")
print(" call is verified functionally by the perplexity anchor in 3.5.)")
print("Read position 0 by eye: its input is the sequence's first token, and its")
print("target is the sequence's SECOND token. target[i] really is input[i+1].")

print("\nFor contrast, here is what the (incorrect) UNSHIFTED alignment would print —")
print("the exact bug the assignment warns about, made visible instead of theoretical:")
print(f"{'pos':>4} | {'input token':<18} | {'WRONG target (=input)':<18}")
for i in range(4):
    in_tok = enc.decode([tokens_in[0, i].item()])
    print(
        f"{i:>4} | {in_tok!r:<18} | {in_tok!r:<18}   <- model would just learn to copy its input"
    )

RESULTS["shift_mismatches"] = n_mismatches
# Out:
# tokens_in   shape: (4, 31)  (dropped LAST position: nothing follows it)
# targets_out shape: (4, 31)  (dropped FIRST position: nothing predicts it)
#
# Inputs vs. targets, decoded to strings, example 0, first 12 positions:
#  pos | input token        | target token       | check
# ------------------------------------------------------------
#    0 | 'Sen'              | 'j'                | OK
#    1 | 'j'                | 'ō'                | OK
#    2 | 'ō'                | ' no'              | OK
#    3 | ' no'              | ' V'               | OK
#    4 | ' V'               | 'alky'             | OK
#    5 | 'alky'             | 'ria'              | OK
#    6 | 'ria'              | ' 3'               | OK
#    7 | ' 3'               | ' :'               | OK
#    8 | ' :'               | ' Un'              | OK
#    9 | ' Un'              | 'recorded'         | OK
#   10 | 'recorded'         | ' Chronicles'      | OK
#   11 | ' Chronicles'      | ' ('               | OK
#
# target-slice check: targets_out matches tokens[:, 1:] at 12/12 positions -> the target tensor is the correct slice.
# (This confirms the slice only. That logits[:, :-1] is aligned to it in the loss
#  call is verified functionally by the perplexity anchor in 3.5.)
# Read position 0 by eye: its input is the sequence's first token, and its
# target is the sequence's SECOND token. target[i] really is input[i+1].
#
# For contrast, here is what the (incorrect) UNSHIFTED alignment would print —
# the exact bug the assignment warns about, made visible instead of theoretical:
#  pos | input token        | WRONG target (=input)
#    0 | 'Sen'              | 'Sen'                <- model would just learn to copy its input
#    1 | 'j'                | 'j'                  <- model would just learn to copy its input
#    2 | 'ō'                | 'ō'                  <- model would just learn to copy its input
#    3 | ' no'              | ' no'                <- model would just learn to copy its input

# %% [markdown]
# ### 3.3 Mask Padding — Confirm the Contributing-Token Count Changes
#
# Sequences in a batch have different lengths, so short ones get padded. A padding
# position is not a prediction; training on it teaches the model to predict padding
# (trivially easy, so the loss *looks* better than it is). The fix is `ignore_index`
# on the padded target positions — and the check is that the count of tokens
# contributing to the mean actually changes.

# %%
print("Building a padded batch from documents of different lengths...\n")
pad_inputs, pad_targets, valid_mask, key_padding_mask, lengths = build_padded_batch(
    train_docs, n_docs=6, pad_to=40
)
print(f"document lengths in this batch : {lengths}")
print(
    f"pad_inputs shape                : {tuple(pad_inputs.shape)}  (batch, padded sequence length)"
)

n_total_positions = valid_mask.numel()
n_valid_positions = int(valid_mask.sum().item())
n_pad_positions = n_total_positions - n_valid_positions
print(f"\ntotal (batch x seq) target positions         : {n_total_positions}")
print(f"positions that are REAL next-token targets    : {n_valid_positions}")
print(f"positions that are PADDING (must be excluded)  : {n_pad_positions}")

pad_inputs_d = pad_inputs.to(DEVICE)
pad_targets_d = pad_targets.to(DEVICE)
input_key_padding_mask = key_padding_mask[:, :-1].to(
    DEVICE
)  # matches pad_inputs' length (tokens[:, :-1])
hidden_pad = model(pad_inputs_d, key_padding_mask=input_key_padding_mask)
logits_pad = head(hidden_pad)

# (a) wrong: no masking -- every position, including padding, counted in the mean
loss_no_mask = F.cross_entropy(
    logits_pad.reshape(-1, VOCAB_SIZE), pad_targets_d.reshape(-1)
)

# (b) right: padding targets set to ignore_index
targets_masked = pad_targets_d.clone()
targets_masked[~valid_mask.to(DEVICE)] = -100
loss_masked = F.cross_entropy(
    logits_pad.reshape(-1, VOCAB_SIZE), targets_masked.reshape(-1), ignore_index=-100
)

contributing_no_mask = n_total_positions
contributing_masked = int((targets_masked != -100).sum().item())

print(
    f"\nloss WITHOUT padding mask : {loss_no_mask.item():.4f}  (averaged over {contributing_no_mask} positions, "
    f"{n_pad_positions} of them padding)"
)
print(
    f"loss WITH padding mask    : {loss_masked.item():.4f}  (averaged over {contributing_masked} positions, all real)"
)
print(
    f"\n==> contributing-token count changed from {contributing_no_mask} to {contributing_masked} "
    f"({n_pad_positions} padding positions removed from the mean)."
)

RESULTS["padding"] = {
    "contributing_before": contributing_no_mask,
    "contributing_after": contributing_masked,
    "loss_before": loss_no_mask.item(),
    "loss_after": loss_masked.item(),
}
# Out:
# Building a padded batch from documents of different lengths...
#
# document lengths in this batch : [7, 40, 40, 40, 6, 40]
# pad_inputs shape                : (6, 39)  (batch, padded sequence length)
#
# total (batch x seq) target positions         : 234
# positions that are REAL next-token targets    : 167
# positions that are PADDING (must be excluded)  : 67
#
# loss WITHOUT padding mask : 10.6834  (averaged over 234 positions, 67 of them padding)
# loss WITH padding mask    : 10.8603  (averaged over 167 positions, all real)
#
# ==> contributing-token count changed from 234 to 167 (67 padding positions removed from the mean).

# %% [markdown]
# ### 3.4 Pack Two Documents, Mask the Boundary
#
# Packing avoids wasting compute on padding by concatenating documents into one
# sequence. But the last token of one document has no relationship to the first
# token of the next — training that pair teaches the model that unrelated things
# follow each other. Below, two real documents are packed **without** a separator
# (to isolate the exact bad pair), the boundary target position is identified, and
# the loss is shown before and after masking it, with the arithmetic checked
# explicitly rather than just asserted.
#
# > **Note on the setup.** This isolated demo concatenates the two documents raw.
# > `pack_documents` (the packer used for the training corpus in Parts 5–6) *does*
# > insert an `<|endoftext|>` token between documents — the model at least sees a
# > separator there — but it still does **not** add a loss mask at the join, so the
# > `EOT → first-token-of-next-doc` pair is still trained on. The demo drops the EOT
# > only so the bad pair is a single, unambiguous position to point at.
#
# On an untrained model the before/after difference is tiny (every position scores
# near `ln V`). The cell after Part 2 re-runs this exact check on the **trained**
# `t+1` head, where the boundary position genuinely stands out.

# %%
long_docs2 = [d for d in train_docs if len(d) >= 24]
doc_a = long_docs2[3][:24]
doc_b = long_docs2[7][:24]
seq = torch.tensor(doc_a + doc_b, dtype=torch.long).unsqueeze(0).to(DEVICE)  # [1, T]

inputs_b = seq[:, :-1]
targets_b = seq[:, 1:].clone()
boundary_idx = (
    len(doc_a) - 1
)  # last token of doc_a (as input) predicts first token of doc_b (as target)

print(
    f"doc_a length = {len(doc_a)}   doc_b length = {len(doc_b)}   packed sequence length = {seq.shape[1]}"
)
print(f"boundary target index = {boundary_idx}")
print(
    f"  input  at boundary : {enc.decode([inputs_b[0, boundary_idx].item()])!r}   (last real token of doc_a)"
)
print(
    f"  target at boundary : {enc.decode([targets_b[0, boundary_idx].item()])!r}   (first real token of doc_b -- UNRELATED to the input)"
)

hidden_b = model(inputs_b)
logits_b = head(hidden_b)

per_token_losses = F.cross_entropy(
    logits_b.reshape(-1, VOCAB_SIZE), targets_b.reshape(-1), reduction="none"
)
loss_before = per_token_losses.mean()
boundary_loss_value = per_token_losses[boundary_idx].item()

targets_masked_b = targets_b.clone()
targets_masked_b[0, boundary_idx] = -100
loss_after = F.cross_entropy(
    logits_b.reshape(-1, VOCAB_SIZE), targets_masked_b.reshape(-1), ignore_index=-100
)

n_before = targets_b.numel()
n_after = int((targets_masked_b != -100).sum().item())

print(
    f"\nloss BEFORE masking the boundary : {loss_before.item():.4f}  (mean over {n_before} positions)"
)
print(
    f"loss AFTER  masking the boundary : {loss_after.item():.4f}  (mean over {n_after} positions)"
)
print(
    f"difference                        : {loss_after.item() - loss_before.item():+.4f}"
)

print(f"\nthe boundary position's own loss  : {boundary_loss_value:.4f}")
check = (loss_before.item() * n_before - boundary_loss_value) / n_after
print(
    f"check -- (sum_before - boundary_loss) / (n-1) = {check:.4f}  (should equal loss_after: {loss_after.item():.4f})"
)

print("\nExplanation: removing the boundary position removes exactly one term from the")
print("mean. On this UNTRAINED model the difference is small, because every position's")
print(
    "loss is close to ln(V) regardless of whether the pair is real -- an untrained head"
)
print("can't tell a genuine continuation from an unrelated document join yet. The cell")
print(
    "after Part 2 repeats this on the TRAINED t+1 head, where the boundary position's"
)
print(
    "own loss sits well above the mean and masking it visibly lowers the reported loss."
)

# keep the exact demo tensors so the post-training cell can re-score them
BOUNDARY_DEMO = dict(inputs=inputs_b, targets=targets_b, boundary_idx=boundary_idx)

RESULTS["boundary"] = {
    "loss_before": loss_before.item(),
    "loss_after": loss_after.item(),
    "boundary_loss": boundary_loss_value,
    "n_before": n_before,
    "n_after": n_after,
    "trained": None,  # filled by the post-Part-2 cell
}
# Out:
# doc_a length = 24   doc_b length = 24   packed sequence length = 48
# boundary target index = 23
#   input  at boundary : ' where'   (last real token of doc_a)
#   target at boundary : 'As'   (first real token of doc_b -- UNRELATED to the input)
#
# loss BEFORE masking the boundary : 10.7940  (mean over 47 positions)
# loss AFTER  masking the boundary : 10.7902  (mean over 46 positions)
# difference                        : -0.0038
#
# the boundary position's own loss  : 10.9666
# check -- (sum_before - boundary_loss) / (n-1) = 10.7902  (should equal loss_after: 10.7902)
#
# Explanation: removing the boundary position removes exactly one term from the
# mean. On this UNTRAINED model the difference is small, because every position's
# loss is close to ln(V) regardless of whether the pair is real -- an untrained head
# can't tell a genuine continuation from an unrelated document join yet. The cell
# after Part 2 repeats this on the TRAINED t+1 head, where the boundary position's
# own loss sits well above the mean and masking it visibly lowers the reported loss.

# %% [markdown]
# ### 3.5 Perplexity — An Untrained Model Should Sit Near Vocabulary Size
#
# `perplexity = exp(mean loss)`, read as "how many equally likely options the model
# is effectively choosing between." An untrained model, having learned nothing, should
# be about as unsure as guessing uniformly over the whole vocabulary: perplexity ≈ V,
# loss ≈ ln(V). If it isn't close, the target alignment is broken and nothing past
# this point can be trusted.

# %%
print("Untrained-model perplexity sanity check\n")

PPL_SEQ_LEN = min(128, MAX_SEQ_LEN)
packed_check = pack_documents(train_docs, seq_len=PPL_SEQ_LEN, n_sequences=8, seed=42)
check_tokens, check_targets, _ = next(
    make_batches(packed_check, seq_len=PPL_SEQ_LEN, batch_size=8)
)
check_tokens = check_tokens.to(DEVICE)
check_targets = check_targets.to(DEVICE)

with torch.no_grad():
    h = model(check_tokens)
    z = head(h)
    loss_untrained = F.cross_entropy(
        z.reshape(-1, VOCAB_SIZE), check_targets.reshape(-1)
    )

ppl_untrained = perplexity(loss_untrained)
ln_v = math.log(VOCAB_SIZE)
rel_gap = abs(loss_untrained.item() - ln_v) / ln_v

print(f"loss (untrained)        : {loss_untrained.item():.4f} nats")
print(f"perplexity (untrained)   : {ppl_untrained:,.1f}")
print(f"vocabulary size V         : {VOCAB_SIZE:,}")
print(f"ln(V)                     : {ln_v:.4f}")
print(f"relative gap from ln(V)   : {rel_gap * 100:.2f}%")
verdict = "PASS" if rel_gap < 0.05 else "CHECK"
print(
    f"\n{verdict}: untrained loss should sit within a few percent of ln(V) -- a random,"
)
print("freshly-initialized head scores the vocabulary close to uniformly, before any")
print("training signal has shaped it.")

RESULTS["perplexity"] = {
    "loss_untrained": loss_untrained.item(),
    "ppl_untrained": ppl_untrained,
    "ln_v": ln_v,
    "vocab_size": VOCAB_SIZE,
    "relative_gap_pct": rel_gap * 100,
}
# Out:
# Untrained-model perplexity sanity check
#
# loss (untrained)        : 10.9328 nats
# perplexity (untrained)   : 55,984.4
# vocabulary size V         : 50,257
# ln(V)                     : 10.8249
# relative gap from ln(V)   : 1.00%
#
# PASS: untrained loss should sit within a few percent of ln(V) -- a random,
# freshly-initialized head scores the vocabulary close to uniformly, before any
# training signal has shaped it.

# %% [markdown]
# ### 3.6 Tied vs. Untied Head Parameter Counts
#
# Tying reuses the input embedding table `W_embed [V, D]` as the output head, adding
# zero new parameters. Untying gives the head its own `[V, D]` matrix. On this
# configuration, that matrix is the single largest block in the whole model.

# %%
untied_head = OutputHead(cfg.vocab_size, cfg.d_model, tied_weight=None).to(DEVICE)

model_params = count_parameters(
    model
)  # trunk, incl. the tok_emb table -- independent of head choice
tied_head_new_params = 0  # tied head adds no new parameters
untied_head_new_params = count_parameters(untied_head)

total_tied = model_params + tied_head_new_params
total_untied = model_params + untied_head_new_params

print(f"trunk parameters (embeddings + blocks + norms) : {model_params:,}")
print(
    f"  of which the [V, D]-sized table                : {model.tok_emb.weight.numel():,}"
)
print()
print(
    f"TIED   total parameters : {total_tied:,}   (head adds {tied_head_new_params:,} new params)"
)
print(
    f"UNTIED total parameters : {total_untied:,}   (head adds {untied_head_new_params:,} new params)"
)
print(f"difference                : {total_untied - total_tied:,} parameters")
print(f"ratio untied / tied        : {total_untied / total_tied:.3f}x")

RESULTS["tied_vs_untied"] = {
    "trunk_params": model_params,
    "total_tied": total_tied,
    "total_untied": total_untied,
    "ratio": total_untied / total_tied,
}
# Out:
# trunk parameters (embeddings + blocks + norms) : 51,692,544
#   of which the [V, D]-sized table                : 25,731,584
#
# TIED   total parameters : 51,692,544   (head adds 0 new params)
# UNTIED total parameters : 77,424,128   (head adds 25,731,584 new params)
# difference                : 25,731,584 parameters
# ratio untied / tied        : 1.498x

# %% [markdown]
# ### 3.7 Peak Memory — Ordinary vs. Chunked Cross-Entropy
#
# Two ways to compute exactly the same objective. **Ordinary:** materialize the full
# `[N, V]` logits tensor, then cross-entropy. **Chunked:** process `chunk_size` tokens
# at a time, accumulate the summed loss, and discard each chunk's logits before
# computing the next — at most `[chunk_size, V]` logits ever exist at once.
#
# First a correctness check on a small tensor (loss *and* gradients must agree), then
# the peak-memory measurement on a large one — with a **byte-by-byte account of where
# the memory goes**, because the naive `[N, V]` figure is not what either path
# actually costs:
#
# - The **backward pass needs the gradient of the logits** — another `[N, V]` tensor.
# - `F.cross_entropy` on `bfloat16` inputs **up-casts the log-softmax to `float32`**
#   for numerical stability — a *third* `[N, V]` tensor, at 2× the width.
# - The chunked path still holds the `[N, D]` hidden state, the `[V, D]` head weight,
#   and **both of their gradients** — none of which shrink with `chunk_size`. That
#   fixed floor, plus one chunk's working set, plus the CUDA context, is why chunked
#   is ~2 GiB and not the ~0.1 GiB the one-chunk logits figure suggests.
#
# The ratio is what matters: the ordinary path's cost grows with `N`, the chunked
# path's does not.

# %%
CHUNK = MEM_CHUNK

print(
    "Correctness check -- does chunking change the loss, or the gradients it produces?\n"
)
check_hidden = torch.randn(4, 16, cfg.d_model, device=DEVICE, requires_grad=True)
check_targets2 = torch.randint(0, VOCAB_SIZE, (4, 16), device=DEVICE)
check_weight = untied_head.weight.detach().clone().requires_grad_(True)

# (a) loss values agree
l_ord = ordinary_cross_entropy(check_hidden, check_weight, check_targets2)
l_chk = chunked_cross_entropy(check_hidden, check_weight, check_targets2, chunk_size=5)
print(f"ordinary loss  : {l_ord.item():.10f}")
print(f"chunked  loss  : {l_chk.item():.10f}")
print(
    f"abs diff        : {abs(l_ord.item() - l_chk.item()):.2e}  (agree to float precision)"
)

# (b) gradients agree too -- chunking must not silently change what the model learns.
# chunked_cross_entropy_backward does its own backward (chunk-by-chunk, freeing each
# chunk's graph before the next), so it needs its own fresh leaf tensors to accumulate into.
h_for_ord = check_hidden.detach().clone().requires_grad_(True)
w_for_ord = check_weight.detach().clone().requires_grad_(True)
ordinary_cross_entropy(h_for_ord, w_for_ord, check_targets2).backward()

h_for_chk = check_hidden.detach().clone().requires_grad_(True)
w_for_chk = check_weight.detach().clone().requires_grad_(True)
chunked_cross_entropy_backward(h_for_chk, w_for_chk, check_targets2, chunk_size=5)

grad_diff_h = (h_for_ord.grad - h_for_chk.grad).abs().max().item()
grad_diff_w = (w_for_ord.grad - w_for_chk.grad).abs().max().item()
print(f"max |grad diff| on hidden : {grad_diff_h:.2e}")
print(f"max |grad diff| on head weight : {grad_diff_w:.2e}")
print(
    "PASS -- chunking changes memory, not the objective or its gradient."
    if max(grad_diff_h, grad_diff_w) < 1e-5
    else "CHECK -- gradients disagree, something in the chunking is wrong."
)

print("\nPeak-memory measurement\n")
N_TOKENS = MEM_N_TOKENS  # flattened batch x seq the loss must score at once
MEM_DTYPE = torch.bfloat16 if DEVICE.type == "cuda" else torch.float32

hidden_mem = torch.randn(
    N_TOKENS, cfg.d_model, device=DEVICE, dtype=MEM_DTYPE, requires_grad=True
)
head_w_mem = torch.randn(
    VOCAB_SIZE, cfg.d_model, device=DEVICE, dtype=MEM_DTYPE, requires_grad=True
)
targets_mem = torch.randint(0, VOCAB_SIZE, (N_TOKENS,), device=DEVICE)


def run_ordinary():
    # naive path: materialize the full [N, V] logits, backward through all of it at once
    loss = ordinary_cross_entropy(
        hidden_mem.unsqueeze(0), head_w_mem, targets_mem.unsqueeze(0)
    )
    loss.backward()
    hidden_mem.grad = None
    head_w_mem.grad = None


def run_chunked():
    # chunked path: backward happens per-chunk *inside* this call, so at most one
    # chunk's [chunk_size, V] logits (and its backward graph) exist at a time
    chunked_cross_entropy_backward(
        hidden_mem.unsqueeze(0), head_w_mem, targets_mem.unsqueeze(0), chunk_size=CHUNK
    )
    hidden_mem.grad = None
    head_w_mem.grad = None


def _mem_reserved(fn):
    if DEVICE.type != "cuda":
        return 0
    torch.cuda.synchronize(DEVICE)
    torch.cuda.reset_peak_memory_stats(DEVICE)
    torch.cuda.empty_cache()
    fn()
    torch.cuda.synchronize(DEVICE)
    return torch.cuda.max_memory_reserved(DEVICE)


peak_ordinary = measure_peak_memory_bytes(run_ordinary, DEVICE)
resv_ordinary = _mem_reserved(run_ordinary)
peak_chunked = measure_peak_memory_bytes(run_chunked, DEVICE)
resv_chunked = _mem_reserved(run_chunked)

D = cfg.d_model
elt = 2 if MEM_DTYPE == torch.bfloat16 else 4  # bytes per element of MEM_DTYPE
nv = N_TOKENS * VOCAB_SIZE
cv = CHUNK * VOCAB_SIZE
GiB = 1024**3

print(
    f"tokens (N)     : {N_TOKENS:,}    vocab (V) : {VOCAB_SIZE:,}    hidden (D) : {D}"
)
print(f"input dtype    : {MEM_DTYPE} ({elt} bytes/elt)    chunk size : {CHUNK:,}")
print()
hg = 2 * N_TOKENS * D * elt / GiB  # hidden [N,D] + its grad
wg = 2 * VOCAB_SIZE * D * elt / GiB  # head weight [V,D] + its grad


def row(label, val, note=""):
    print(f"    {label:<34}: {val:7.2f} GiB   {note}")


print("WHERE THE BYTES GO  (theoretical, before allocator rounding)")
print("-" * 72)
print("  ORDINARY -- one [N, V] pass")
row(f"logits  [N, V]  x{elt}", nv * elt / GiB)
row(
    "log-softmax  [N, V]  x4 (fp32)",
    nv * 4 / GiB,
    "<- F.cross_entropy up-casts for stability",
)
row(
    f"grad of logits  [N, V]  x{elt}",
    nv * elt / GiB,
    "<- the backward pass needs it too",
)
row("hidden + grad  (2 x [N,D])", hg)
row("head weight + grad  (2 x [V,D])", wg)
pred_ord = (nv * elt + nv * 4 + nv * elt) / GiB + hg + wg
print(f"    {'= predicted peak':<34}: {pred_ord:7.2f} GiB")
print()
print(f"  CHUNKED -- {N_TOKENS // CHUNK} passes of {CHUNK:,} tokens")
row(
    f"one chunk: logits + fp32 log-softmax + grad",
    (cv * elt + cv * 4 + cv * elt) / GiB,
    "<- transient, freed each pass",
)
row("hidden + grad  (2 x [N,D])", hg, "<- does NOT shrink with chunk_size")
row("head weight + grad  (2 x [V,D])", wg, "<- does NOT shrink with chunk_size")
pred_chk = (cv * elt + cv * 4 + cv * elt) / GiB + hg + wg
print(
    f"    {'= predicted peak':<34}: {pred_chk:7.2f} GiB   + CUDA context / cuBLAS workspace (~1 GiB, fixed)"
)
print()
print("MEASURED  (torch.cuda.max_memory_allocated / _reserved)")
print("-" * 66)
print(
    f"  ORDINARY : allocated {human_bytes(peak_ordinary)}   reserved {human_bytes(resv_ordinary)}"
)
print(
    f"  CHUNKED  : allocated {human_bytes(peak_chunked)}   reserved {human_bytes(resv_chunked)}"
)
if peak_chunked > 0:
    ratio_mem = peak_ordinary / peak_chunked
    print(f"\n  ratio (ordinary / chunked, allocated) : {ratio_mem:.1f}x")
    print(
        f"  allocated - predicted, ordinary       : {human_bytes(peak_ordinary - pred_ord * GiB)}  (allocator + context)"
    )
    print(
        f"  allocated - predicted, chunked        : {human_bytes(peak_chunked - pred_chk * GiB)}  (CUDA context is a fixed cost)"
    )
    print(f"\n  The chunked path pays a ~fixed cost; the ordinary path's grows with N.")
    print(
        f"  At the {SEQ_LEN}-token context this model trains at, that gap is the whole point."
    )
else:
    ratio_mem = None
    print("\n  (CUDA not available -- CPU has no equivalent peak-memory counter; the")
    print("   theoretical account above is the takeaway on this device.)")

RESULTS["memory"] = {
    "n_tokens": N_TOKENS,
    "chunk_size": CHUNK,
    "dtype": str(MEM_DTYPE),
    "d_model": D,
    "predicted_ordinary_gib": round(pred_ord, 2),
    "predicted_chunked_gib": round(pred_chk, 2),
    "peak_ordinary_bytes": int(peak_ordinary),
    "peak_chunked_bytes": int(peak_chunked),
    "reserved_ordinary_bytes": int(resv_ordinary),
    "reserved_chunked_bytes": int(resv_chunked),
    "ratio": ratio_mem,
}
# Out:
# Correctness check -- does chunking change the loss, or the gradients it produces?
#
# ordinary loss  : 10.9774618149
# chunked  loss  : 10.9774608612
# abs diff        : 9.54e-07  (agree to float precision)
# max |grad diff| on hidden : 2.33e-09
# max |grad diff| on head weight : 2.61e-08
# PASS -- chunking changes memory, not the objective or its gradient.
#
# Peak-memory measurement
#
# tokens (N)     : 32,768    vocab (V) : 50,257    hidden (D) : 512
# input dtype    : torch.bfloat16 (2 bytes/elt)    chunk size : 2,048
#
# WHERE THE BYTES GO  (theoretical, before allocator rounding)
# ------------------------------------------------------------------------
#   ORDINARY -- one [N, V] pass
#     logits  [N, V]  x2                :    3.07 GiB
#     log-softmax  [N, V]  x4 (fp32)    :    6.13 GiB   <- F.cross_entropy up-casts for stability
#     grad of logits  [N, V]  x2        :    3.07 GiB   <- the backward pass needs it too
#     hidden + grad  (2 x [N,D])        :    0.06 GiB
#     head weight + grad  (2 x [V,D])   :    0.10 GiB
#     = predicted peak                  :   12.43 GiB
#
#   CHUNKED -- 16 passes of 2,048 tokens
#     one chunk: logits + fp32 log-softmax + grad:    0.77 GiB   <- transient, freed each pass
#     hidden + grad  (2 x [N,D])        :    0.06 GiB   <- does NOT shrink with chunk_size
#     head weight + grad  (2 x [V,D])   :    0.10 GiB   <- does NOT shrink with chunk_size
#     = predicted peak                  :    0.93 GiB   + CUDA context / cuBLAS workspace (~1 GiB, fixed)
#
# MEASURED  (torch.cuda.max_memory_allocated / _reserved)
# ------------------------------------------------------------------
#   ORDINARY : allocated 10.61 GiB   reserved 10.68 GiB
#   CHUNKED  : allocated 2.25 GiB   reserved 2.44 GiB
#
#   ratio (ordinary / chunked, allocated) : 4.7x
#   measured - predicted, ordinary        : -1.82 GiB  (logits + log-softmax do not fully coexist -> measured is lower)
#   measured - predicted, chunked         : +1.32 GiB  (CUDA context + cuBLAS workspace, a fixed cost)
#
#   The chunked path pays a ~fixed cost; the ordinary path's grows with N.
#   At the 512-token context this model trains at, that gap is the whole point.

# %%
# Part 1's exploratory tensors (the large memory-measurement buffers, the
# untied-head duplicate) are no longer needed. Free them explicitly before
# Part 2 trains three more models on the same small GPU.
del (
    hidden_mem,
    head_w_mem,
    targets_mem,
    untied_head,
    model,
    head,
    check_hidden,
    check_targets2,
    check_weight,
    h_for_ord,
    w_for_ord,
    h_for_chk,
    w_for_chk,
)
if DEVICE.type == "cuda":
    torch.cuda.empty_cache()
    print(
        f"GPU memory freed. currently allocated: {human_bytes(torch.cuda.memory_allocated(DEVICE))}"
    )
# Out:
# GPU memory freed. currently allocated: 863.02 MiB

# %% [markdown]
# ### Part 1 Recap
#
# Every checklist item now has a number behind it: shapes are printed and explained,
# the shift is verified by eye against decoded strings, padding and document
# boundaries are masked with the contributing-token count shown to move, perplexity
# lands near `ln(V)`, tied vs. untied parameter counts are compared, and peak memory
# for the two cross-entropy implementations is measured with an explicit ratio. The
# full "seven numbers" table is assembled in the final summary section, after Part 2.

# %% [markdown]
# ## 4. Experiment Tracking with Aim
#
# [Aim](https://aimstack.io/) tracks this run's hyperparameters, per-step metrics, and
# logs, stored in a local `.aim` repo inside this project. Everything logged below —
# losses, perplexities, both MTP heads — is queryable later via `aim up`, without
# re-running anything.

# %%
from aim import Run, Repo

repo = Repo(".", init=True)
aim_run = Run(repo=repo, experiment="session9-loss-harness")
aim_run["hparams"] = {
    "d_model": cfg.d_model,
    "n_layers": cfg.n_layers,
    "n_heads": cfg.n_heads,
    "d_ff": cfg.d_ff,
    "vocab_size": cfg.vocab_size,
    "max_seq_len": cfg.max_seq_len,
    "tokenizer": "gpt2 (tiktoken)",
    "dataset": DATASET_CONFIG,
    "seq_len": SEQ_LEN,
    "batch_size": BATCH_SIZE,
    "n_steps": N_STEPS,
    "smoke": SMOKE,
}
print(f"Aim run hash   : {aim_run.hash}")
print(f"Aim repo path   : {os.path.abspath('.')}")
print("hparams logged   :", json.dumps(aim_run["hparams"], indent=2))
# Out:
# Aim run hash   : 40951568012744718a1101ab
# Aim repo path   : /home/ravi.naik/learning/era/ERA/v5/session9/loss_harness
# hparams logged   : {
#   "batch_size": 12,
#   "d_ff": 1408,
#   "d_model": 512,
#   "dataset": "wikitext-103-raw-v1",
#   "max_seq_len": 512,
#   "n_heads": 8,
#   "n_layers": 8,
#   "n_steps": 4000,
#   "seq_len": 512,
#   "smoke": false,
#   "tokenizer": "gpt2 (tiktoken)",
#   "vocab_size": 50257
# }

# %% [markdown]
# ## 5. Baseline Training — Single Head, Predicts t+1
#
# A training run of the ordinary single-head model (one tied `t+1` head, the standard
# setup) on the packed corpus, logging loss and perplexity to Aim every step. This is
# the reference `t+1` curve; Part 2 then trains two untied heads (`t+1` and `t+2`)
# side by side on the same trunk, data, step count, and seed.

# %%
print(
    f"Training baseline (t+1 only): seq_len={SEQ_LEN} batch_size={BATCH_SIZE} steps={N_STEPS}\n"
)

set_seed(1337)
baseline_model = TinyGPT(cfg).to(DEVICE)
baseline_head = OutputHead(
    cfg.vocab_size, cfg.d_model, tied_weight=baseline_model.tok_emb.weight
).to(DEVICE)
opt = torch.optim.AdamW(collect_params(baseline_model, baseline_head), lr=3e-4)

packed_train = pack_documents(
    train_docs, seq_len=SEQ_LEN, n_sequences=BATCH_SIZE * (N_STEPS + 8), seed=0
)

baseline_losses = []
t0 = time.time()
step = 0
for tokens_i, targets_i, _boundary_i in make_batches(packed_train, SEQ_LEN, BATCH_SIZE):
    if step >= N_STEPS:
        break
    tokens_i = tokens_i.to(DEVICE)
    targets_i = targets_i.to(DEVICE)

    h = baseline_model(tokens_i)
    z = baseline_head(h)
    loss = F.cross_entropy(z.reshape(-1, VOCAB_SIZE), targets_i.reshape(-1))

    opt.zero_grad()
    loss.backward()
    opt.step()

    baseline_losses.append(loss.item())
    aim_run.track(loss.item(), name="loss", context={"subset": "baseline"}, step=step)
    aim_run.track(
        perplexity(loss.item()),
        name="perplexity",
        context={"subset": "baseline"},
        step=step,
    )

    if step % 25 == 0 or step == N_STEPS - 1:
        print(
            f"step {step:4d}/{N_STEPS} | loss {loss.item():.4f} | ppl {perplexity(loss.item()):9.1f} "
            f"| elapsed {time.time() - t0:5.1f}s"
        )
    step += 1

print(f"\nbaseline training done in {time.time() - t0:.1f}s")
print(
    f"loss: {baseline_losses[0]:.4f} -> {baseline_losses[-1]:.4f}  "
    f"(perplexity {perplexity(baseline_losses[0]):.0f} -> {perplexity(baseline_losses[-1]):.1f})"
)
# Out:
# Training baseline (t+1 only): seq_len=512 batch_size=12 steps=4000
#
# step    0/4000 | loss 10.9386 | ppl   56307.3 | elapsed   0.8s
# step   25/4000 | loss 7.7598 | ppl    2344.4 | elapsed   4.9s
# step   50/4000 | loss 7.5308 | ppl    1864.5 | elapsed   9.0s
# step   75/4000 | loss 7.0994 | ppl    1211.2 | elapsed  13.1s
# step  100/4000 | loss 7.0129 | ppl    1110.9 | elapsed  17.2s
# step  125/4000 | loss 6.9178 | ppl    1010.1 | elapsed  21.4s
# step  150/4000 | loss 6.8323 | ppl     927.3 | elapsed  25.5s
# step  175/4000 | loss 6.5870 | ppl     725.6 | elapsed  29.7s
# step  200/4000 | loss 6.6229 | ppl     752.2 | elapsed  33.9s
# step  225/4000 | loss 6.5985 | ppl     734.0 | elapsed  38.2s
# step  250/4000 | loss 6.4752 | ppl     648.8 | elapsed  42.4s
# step  275/4000 | loss 6.4425 | ppl     628.0 | elapsed  46.7s
# step  300/4000 | loss 6.3446 | ppl     569.4 | elapsed  50.9s
# step  325/4000 | loss 6.4021 | ppl     603.1 | elapsed  55.2s
# step  350/4000 | loss 6.3353 | ppl     564.1 | elapsed  59.5s
# step  375/4000 | loss 6.1764 | ppl     481.3 | elapsed  63.7s
# step  400/4000 | loss 6.2540 | ppl     520.1 | elapsed  68.0s
# step  425/4000 | loss 6.2416 | ppl     513.7 | elapsed  72.3s
# step  450/4000 | loss 6.2717 | ppl     529.4 | elapsed  76.6s
# step  475/4000 | loss 6.2561 | ppl     521.2 | elapsed  80.9s
# step  500/4000 | loss 6.0278 | ppl     414.8 | elapsed  85.2s
# step  525/4000 | loss 6.1670 | ppl     476.7 | elapsed  89.4s
# step  550/4000 | loss 6.1536 | ppl     470.4 | elapsed  93.7s
# step  575/4000 | loss 5.9986 | ppl     402.9 | elapsed  98.0s
# step  600/4000 | loss 6.0818 | ppl     437.8 | elapsed 102.3s
# step  625/4000 | loss 6.0959 | ppl     444.0 | elapsed 106.6s
# step  650/4000 | loss 5.8524 | ppl     348.1 | elapsed 110.9s
# step  675/4000 | loss 5.8217 | ppl     337.5 | elapsed 115.2s
# step  700/4000 | loss 5.7615 | ppl     317.8 | elapsed 119.4s
# step  725/4000 | loss 5.7967 | ppl     329.2 | elapsed 123.7s
# step  750/4000 | loss 5.7789 | ppl     323.4 | elapsed 128.0s
# step  775/4000 | loss 5.8151 | ppl     335.3 | elapsed 132.3s
# step  800/4000 | loss 5.8685 | ppl     353.7 | elapsed 136.6s
# step  825/4000 | loss 5.9747 | ppl     393.4 | elapsed 140.9s
# step  850/4000 | loss 5.7322 | ppl     308.6 | elapsed 145.2s
# step  875/4000 | loss 5.6324 | ppl     279.3 | elapsed 149.5s
# step  900/4000 | loss 5.6295 | ppl     278.5 | elapsed 153.8s
# step  925/4000 | loss 5.6985 | ppl     298.4 | elapsed 158.0s
# step  950/4000 | loss 5.6248 | ppl     277.2 | elapsed 162.3s
# step  975/4000 | loss 5.6824 | ppl     293.7 | elapsed 166.6s
# step 1000/4000 | loss 5.5449 | ppl     255.9 | elapsed 170.9s
# step 1025/4000 | loss 5.4990 | ppl     244.4 | elapsed 175.2s
# step 1050/4000 | loss 5.6014 | ppl     270.8 | elapsed 179.5s
# step 1075/4000 | loss 5.4686 | ppl     237.1 | elapsed 183.8s
# step 1100/4000 | loss 5.4384 | ppl     230.1 | elapsed 188.0s
# step 1125/4000 | loss 5.4451 | ppl     231.6 | elapsed 192.3s
# step 1150/4000 | loss 5.3784 | ppl     216.7 | elapsed 196.6s
# step 1175/4000 | loss 5.6111 | ppl     273.4 | elapsed 200.9s
# step 1200/4000 | loss 5.5620 | ppl     260.3 | elapsed 205.2s
# step 1225/4000 | loss 5.4318 | ppl     228.6 | elapsed 209.5s
# step 1250/4000 | loss 5.4709 | ppl     237.7 | elapsed 213.8s
# step 1275/4000 | loss 5.4283 | ppl     227.8 | elapsed 218.1s
# step 1300/4000 | loss 5.3927 | ppl     219.8 | elapsed 222.3s
# step 1325/4000 | loss 5.2848 | ppl     197.3 | elapsed 226.6s
# step 1350/4000 | loss 5.1735 | ppl     176.5 | elapsed 230.9s
# step 1375/4000 | loss 5.2911 | ppl     198.6 | elapsed 235.2s
# step 1400/4000 | loss 5.2687 | ppl     194.2 | elapsed 239.5s
# step 1425/4000 | loss 5.2016 | ppl     181.6 | elapsed 243.8s
# step 1450/4000 | loss 5.2958 | ppl     199.5 | elapsed 248.0s
# step 1475/4000 | loss 5.3270 | ppl     205.8 | elapsed 252.3s
# step 1500/4000 | loss 5.1898 | ppl     179.4 | elapsed 256.6s
# step 1525/4000 | loss 5.2965 | ppl     199.6 | elapsed 260.9s
# step 1550/4000 | loss 5.1380 | ppl     170.4 | elapsed 265.2s
# step 1575/4000 | loss 5.2657 | ppl     193.6 | elapsed 269.5s
# step 1600/4000 | loss 5.1214 | ppl     167.6 | elapsed 273.7s
# step 1625/4000 | loss 5.0455 | ppl     155.3 | elapsed 278.0s
# step 1650/4000 | loss 5.2145 | ppl     183.9 | elapsed 282.3s
# step 1675/4000 | loss 5.0006 | ppl     148.5 | elapsed 286.6s
# step 1700/4000 | loss 5.1492 | ppl     172.3 | elapsed 290.9s
# step 1725/4000 | loss 4.9699 | ppl     144.0 | elapsed 295.2s
# step 1750/4000 | loss 5.1605 | ppl     174.2 | elapsed 299.4s
# step 1775/4000 | loss 5.2589 | ppl     192.3 | elapsed 303.7s
# step 1800/4000 | loss 5.1611 | ppl     174.3 | elapsed 308.0s
# step 1825/4000 | loss 4.9539 | ppl     141.7 | elapsed 312.3s
# step 1850/4000 | loss 4.8840 | ppl     132.2 | elapsed 316.6s
# step 1875/4000 | loss 5.0270 | ppl     152.5 | elapsed 320.8s
# step 1900/4000 | loss 5.0837 | ppl     161.4 | elapsed 325.1s
# step 1925/4000 | loss 5.0325 | ppl     153.3 | elapsed 329.4s
# step 1950/4000 | loss 5.0406 | ppl     154.6 | elapsed 333.7s
# step 1975/4000 | loss 4.8738 | ppl     130.8 | elapsed 338.0s
# step 2000/4000 | loss 5.1074 | ppl     165.2 | elapsed 342.2s
# step 2025/4000 | loss 4.9578 | ppl     142.3 | elapsed 346.5s
# step 2050/4000 | loss 4.9796 | ppl     145.4 | elapsed 350.8s
# step 2075/4000 | loss 4.9009 | ppl     134.4 | elapsed 355.1s
# step 2100/4000 | loss 5.0896 | ppl     162.3 | elapsed 359.4s
# step 2125/4000 | loss 4.9850 | ppl     146.2 | elapsed 363.6s
# step 2150/4000 | loss 4.9162 | ppl     136.5 | elapsed 367.9s
# step 2175/4000 | loss 4.9408 | ppl     139.9 | elapsed 372.2s
# step 2200/4000 | loss 5.0634 | ppl     158.1 | elapsed 376.5s
# step 2225/4000 | loss 4.9656 | ppl     143.4 | elapsed 380.8s
# step 2250/4000 | loss 4.7367 | ppl     114.1 | elapsed 385.0s
# step 2275/4000 | loss 4.8026 | ppl     121.8 | elapsed 389.3s
# step 2300/4000 | loss 4.8661 | ppl     129.8 | elapsed 393.6s
# step 2325/4000 | loss 4.6054 | ppl     100.0 | elapsed 397.9s
# step 2350/4000 | loss 4.8114 | ppl     122.9 | elapsed 402.2s
# step 2375/4000 | loss 4.9907 | ppl     147.0 | elapsed 406.4s
# step 2400/4000 | loss 4.7103 | ppl     111.1 | elapsed 410.7s
# step 2425/4000 | loss 4.7488 | ppl     115.5 | elapsed 415.0s
# step 2450/4000 | loss 4.8726 | ppl     130.7 | elapsed 419.3s
# step 2475/4000 | loss 4.8686 | ppl     130.1 | elapsed 423.5s
# step 2500/4000 | loss 4.8858 | ppl     132.4 | elapsed 427.8s
# step 2525/4000 | loss 4.8882 | ppl     132.7 | elapsed 432.1s
# step 2550/4000 | loss 4.8704 | ppl     130.4 | elapsed 436.4s
# step 2575/4000 | loss 4.9458 | ppl     140.6 | elapsed 440.6s
# step 2600/4000 | loss 4.7848 | ppl     119.7 | elapsed 444.9s
# step 2625/4000 | loss 4.9053 | ppl     135.0 | elapsed 449.2s
# step 2650/4000 | loss 4.7148 | ppl     111.6 | elapsed 453.5s
# step 2675/4000 | loss 4.8673 | ppl     130.0 | elapsed 457.7s
# step 2700/4000 | loss 4.5686 | ppl      96.4 | elapsed 462.0s
# step 2725/4000 | loss 4.7491 | ppl     115.5 | elapsed 466.3s
# step 2750/4000 | loss 4.8740 | ppl     130.8 | elapsed 470.5s
# step 2775/4000 | loss 4.7439 | ppl     114.9 | elapsed 474.8s
# step 2800/4000 | loss 4.8322 | ppl     125.5 | elapsed 479.1s
# step 2825/4000 | loss 4.6965 | ppl     109.6 | elapsed 483.4s
# step 2850/4000 | loss 4.6846 | ppl     108.3 | elapsed 487.6s
# step 2875/4000 | loss 4.6099 | ppl     100.5 | elapsed 491.9s
# step 2900/4000 | loss 4.6943 | ppl     109.3 | elapsed 496.2s
# step 2925/4000 | loss 4.6734 | ppl     107.1 | elapsed 500.5s
# step 2950/4000 | loss 4.6618 | ppl     105.8 | elapsed 504.7s
# step 2975/4000 | loss 4.6623 | ppl     105.9 | elapsed 509.0s
# step 3000/4000 | loss 4.5029 | ppl      90.3 | elapsed 513.3s
# step 3025/4000 | loss 4.6754 | ppl     107.3 | elapsed 517.5s
# step 3050/4000 | loss 4.7974 | ppl     121.2 | elapsed 521.8s
# step 3075/4000 | loss 4.6475 | ppl     104.3 | elapsed 526.1s
# step 3100/4000 | loss 4.7599 | ppl     116.7 | elapsed 530.3s
# step 3125/4000 | loss 4.5842 | ppl      97.9 | elapsed 534.6s
# step 3150/4000 | loss 4.7102 | ppl     111.1 | elapsed 538.9s
# step 3175/4000 | loss 4.6003 | ppl      99.5 | elapsed 543.2s
# step 3200/4000 | loss 4.6207 | ppl     101.6 | elapsed 547.4s
# step 3225/4000 | loss 4.6300 | ppl     102.5 | elapsed 551.7s
# step 3250/4000 | loss 4.5278 | ppl      92.6 | elapsed 556.0s
# step 3275/4000 | loss 4.6541 | ppl     105.0 | elapsed 560.2s
# step 3300/4000 | loss 4.5970 | ppl      99.2 | elapsed 564.5s
# step 3325/4000 | loss 4.6563 | ppl     105.2 | elapsed 568.8s
# step 3350/4000 | loss 4.6681 | ppl     106.5 | elapsed 573.1s
# step 3375/4000 | loss 4.6854 | ppl     108.4 | elapsed 577.4s
# step 3400/4000 | loss 4.4297 | ppl      83.9 | elapsed 581.6s
# step 3425/4000 | loss 4.7319 | ppl     113.5 | elapsed 585.9s
# step 3450/4000 | loss 4.3892 | ppl      80.6 | elapsed 590.2s
# step 3475/4000 | loss 4.5057 | ppl      90.5 | elapsed 594.5s
# step 3500/4000 | loss 4.5697 | ppl      96.5 | elapsed 598.8s
# step 3525/4000 | loss 4.6856 | ppl     108.4 | elapsed 603.0s
# step 3550/4000 | loss 4.4926 | ppl      89.4 | elapsed 607.3s
# step 3575/4000 | loss 4.5109 | ppl      91.0 | elapsed 611.6s
# step 3600/4000 | loss 4.5475 | ppl      94.4 | elapsed 615.9s
# step 3625/4000 | loss 4.6778 | ppl     107.5 | elapsed 620.2s
# step 3650/4000 | loss 4.5306 | ppl      92.8 | elapsed 624.4s
# step 3675/4000 | loss 4.6555 | ppl     105.2 | elapsed 628.7s
# step 3700/4000 | loss 4.6928 | ppl     109.2 | elapsed 633.0s
# step 3725/4000 | loss 4.4919 | ppl      89.3 | elapsed 637.3s
# step 3750/4000 | loss 4.5509 | ppl      94.7 | elapsed 641.6s
# step 3775/4000 | loss 4.5420 | ppl      93.9 | elapsed 645.8s
# step 3800/4000 | loss 4.6803 | ppl     107.8 | elapsed 650.1s
# step 3825/4000 | loss 4.5113 | ppl      91.0 | elapsed 654.4s
# step 3850/4000 | loss 4.4328 | ppl      84.2 | elapsed 658.7s
# step 3875/4000 | loss 4.5867 | ppl      98.2 | elapsed 663.0s
# step 3900/4000 | loss 4.6333 | ppl     102.8 | elapsed 667.2s
# step 3925/4000 | loss 4.5293 | ppl      92.7 | elapsed 671.5s
# step 3950/4000 | loss 4.3610 | ppl      78.3 | elapsed 675.8s
# step 3975/4000 | loss 4.6121 | ppl     100.7 | elapsed 680.0s
# step 3999/4000 | loss 4.6533 | ppl     104.9 | elapsed 684.1s
#
# baseline training done in 684.1s
# loss: 10.9386 -> 4.6533  (perplexity 56307 -> 104.9)

# %%
fig, ax = plt.subplots(figsize=(8, 4.5))
ax.plot(baseline_losses, color=COLORS["head1"], linewidth=2)
ax.set_xlabel("training step")
ax.set_ylabel("loss (nats)")
ax.set_title("Baseline single-head (t+1) training loss")
plt.tight_layout()
plt.savefig("assets/baseline_loss.png", dpi=130)
plt.show()

# %% [markdown]
# ## 6. Part 2 — A Second Output Head Predicting t+2
#
# Same trunk architecture, same packed corpus, same step count and seed as the
# baseline above (the only batching difference is a `seq_len+2` window so every input
# position has both a `t+1` and a `t+2` target). Two output heads sit on top of the
# shared hidden state: **Head 1** predicts `t+1`, **Head 2** predicts `t+2`. Both are
# **untied and architecturally identical** — the only difference is the target — so
# the loss gap between them measures exactly one thing: how much harder it is to
# predict two tokens ahead than one. The two losses are reported separately and
# summed; the sum is what gets optimized (added, not averaged, so each head pulls on
# the shared trunk with equal weight).

# %%
def make_mtp_batches(packed, seq_len, batch_size):
    """Like make_batches, but yields a seq_len+2 window so we have both
    a t+1 and a t+2 target for every input position."""
    n_positions = (len(packed.ids) - 2) // seq_len
    ids = packed.ids[: n_positions * seq_len + 2]
    chunks = []
    for i in range(n_positions):
        s = i * seq_len
        chunks.append(ids[s : s + seq_len + 2])
    chunks = torch.stack(chunks)
    for i in range(0, len(chunks) - batch_size + 1, batch_size):
        block = chunks[i : i + batch_size]
        tok = block[:, :-2]
        tgt1 = block[:, 1:-1]
        tgt2 = block[:, 2:]
        yield tok, tgt1, tgt2


print(
    f"Training MTP model (t+1 and t+2 jointly): seq_len={SEQ_LEN} batch_size={BATCH_SIZE} steps={N_STEPS}\n"
)

set_seed(1337)
mtp_model = TinyGPT(cfg).to(DEVICE)
# Both heads UNTIED and architecturally identical -- the only thing that differs
# is the target (t+1 vs t+2). Tying Head 1 to the embedding (as the baseline does)
# would confound the comparison: any loss gap could be "t+2 is harder" OR "the
# tied head is more constrained." Untying both isolates the prediction-distance
# effect, which is what Part 2 is actually asking about.
head_t1 = OutputHead(cfg.vocab_size, cfg.d_model, tied_weight=None).to(DEVICE)
head_t2 = OutputHead(cfg.vocab_size, cfg.d_model, tied_weight=None).to(DEVICE)

mtp_params = collect_params(mtp_model, head_t1, head_t2)
opt2 = torch.optim.AdamW(mtp_params, lr=3e-4)

n_mtp_total = (
    count_parameters(mtp_model) + count_parameters(head_t1) + count_parameters(head_t2)
)
print(
    f"MTP model total parameters (trunk + untied head1 + untied head2): {n_mtp_total:,}"
)
print(
    f"  each output head is a [{cfg.vocab_size:,} x {cfg.d_model}] matrix = {count_parameters(head_t2):,} params\n"
)

packed_train2 = pack_documents(
    train_docs, seq_len=SEQ_LEN, n_sequences=BATCH_SIZE * (N_STEPS + 8), seed=0
)

loss1_hist, loss2_hist, sum_hist = [], [], []
t0 = time.time()
step = 0
for tokens_i, t1_i, t2_i in make_mtp_batches(packed_train2, SEQ_LEN, BATCH_SIZE):
    if step >= N_STEPS:
        break
    tokens_i = tokens_i.to(DEVICE)
    t1_i = t1_i.to(DEVICE)
    t2_i = t2_i.to(DEVICE)

    h = mtp_model(tokens_i)
    z1 = head_t1(h)
    z2 = head_t2(h)
    loss1 = F.cross_entropy(z1.reshape(-1, VOCAB_SIZE), t1_i.reshape(-1))
    loss2 = F.cross_entropy(z2.reshape(-1, VOCAB_SIZE), t2_i.reshape(-1))
    loss_sum = loss1 + loss2

    opt2.zero_grad()
    loss_sum.backward()
    opt2.step()

    loss1_hist.append(loss1.item())
    loss2_hist.append(loss2.item())
    sum_hist.append(loss_sum.item())

    aim_run.track(
        loss1.item(), name="loss", context={"subset": "mtp_head1_t+1"}, step=step
    )
    aim_run.track(
        loss2.item(), name="loss", context={"subset": "mtp_head2_t+2"}, step=step
    )
    aim_run.track(
        loss_sum.item(), name="loss", context={"subset": "mtp_sum"}, step=step
    )

    if step % 25 == 0 or step == N_STEPS - 1:
        print(
            f"step {step:4d}/{N_STEPS} | L1(t+1) {loss1.item():.4f} | L2(t+2) {loss2.item():.4f} "
            f"| sum {loss_sum.item():.4f} | gap(L2-L1) {loss2.item() - loss1.item():+.4f}"
        )
    step += 1

print(f"\nMTP training done in {time.time() - t0:.1f}s")
# Out:
# Training MTP model (t+1 and t+2 jointly): seq_len=512 batch_size=12 steps=4000
#
# MTP model total parameters (trunk + untied head1 + untied head2): 103,155,712
#   each output head is a [50,257 x 512] matrix = 25,731,584 params
#
# step    0/4000 | L1(t+1) 10.8917 | L2(t+2) 10.9536 | sum 21.8453 | gap(L2-L1) +0.0618
# step   25/4000 | L1(t+1) 7.8257 | L2(t+2) 7.8635 | sum 15.6892 | gap(L2-L1) +0.0378
# step   50/4000 | L1(t+1) 7.6075 | L2(t+2) 7.6133 | sum 15.2208 | gap(L2-L1) +0.0059
# step   75/4000 | L1(t+1) 7.2395 | L2(t+2) 7.4443 | sum 14.6838 | gap(L2-L1) +0.2048
# step  100/4000 | L1(t+1) 7.0580 | L2(t+2) 7.4249 | sum 14.4829 | gap(L2-L1) +0.3669
# step  125/4000 | L1(t+1) 6.9225 | L2(t+2) 7.3644 | sum 14.2869 | gap(L2-L1) +0.4419
# step  150/4000 | L1(t+1) 6.8251 | L2(t+2) 7.3129 | sum 14.1380 | gap(L2-L1) +0.4877
# step  175/4000 | L1(t+1) 6.5764 | L2(t+2) 7.1456 | sum 13.7220 | gap(L2-L1) +0.5692
# step  200/4000 | L1(t+1) 6.6252 | L2(t+2) 7.2080 | sum 13.8332 | gap(L2-L1) +0.5828
# step  225/4000 | L1(t+1) 6.6040 | L2(t+2) 7.2528 | sum 13.8568 | gap(L2-L1) +0.6488
# step  250/4000 | L1(t+1) 6.4726 | L2(t+2) 7.1444 | sum 13.6170 | gap(L2-L1) +0.6717
# step  275/4000 | L1(t+1) 6.4451 | L2(t+2) 7.1715 | sum 13.6166 | gap(L2-L1) +0.7264
# step  300/4000 | L1(t+1) 6.3403 | L2(t+2) 7.0545 | sum 13.3948 | gap(L2-L1) +0.7141
# step  325/4000 | L1(t+1) 6.3799 | L2(t+2) 7.1315 | sum 13.5114 | gap(L2-L1) +0.7516
# step  350/4000 | L1(t+1) 6.3332 | L2(t+2) 7.1112 | sum 13.4444 | gap(L2-L1) +0.7780
# step  375/4000 | L1(t+1) 6.1683 | L2(t+2) 6.9710 | sum 13.1393 | gap(L2-L1) +0.8026
# step  400/4000 | L1(t+1) 6.2482 | L2(t+2) 7.0650 | sum 13.3132 | gap(L2-L1) +0.8168
# step  425/4000 | L1(t+1) 6.2315 | L2(t+2) 7.0537 | sum 13.2852 | gap(L2-L1) +0.8222
# step  450/4000 | L1(t+1) 6.2785 | L2(t+2) 7.1117 | sum 13.3902 | gap(L2-L1) +0.8332
# step  475/4000 | L1(t+1) 6.2439 | L2(t+2) 7.0748 | sum 13.3187 | gap(L2-L1) +0.8309
# step  500/4000 | L1(t+1) 6.0230 | L2(t+2) 6.8963 | sum 12.9194 | gap(L2-L1) +0.8733
# step  525/4000 | L1(t+1) 6.1694 | L2(t+2) 7.0097 | sum 13.1791 | gap(L2-L1) +0.8403
# step  550/4000 | L1(t+1) 6.1617 | L2(t+2) 6.9964 | sum 13.1581 | gap(L2-L1) +0.8346
# step  575/4000 | L1(t+1) 6.0228 | L2(t+2) 6.9233 | sum 12.9461 | gap(L2-L1) +0.9006
# step  600/4000 | L1(t+1) 6.0902 | L2(t+2) 7.0105 | sum 13.1007 | gap(L2-L1) +0.9203
# step  625/4000 | L1(t+1) 6.1104 | L2(t+2) 6.9749 | sum 13.0853 | gap(L2-L1) +0.8646
# step  650/4000 | L1(t+1) 5.8729 | L2(t+2) 6.7752 | sum 12.6481 | gap(L2-L1) +0.9023
# step  675/4000 | L1(t+1) 5.8292 | L2(t+2) 6.7347 | sum 12.5639 | gap(L2-L1) +0.9055
# step  700/4000 | L1(t+1) 5.7760 | L2(t+2) 6.7042 | sum 12.4802 | gap(L2-L1) +0.9282
# step  725/4000 | L1(t+1) 5.8108 | L2(t+2) 6.7391 | sum 12.5499 | gap(L2-L1) +0.9284
# step  750/4000 | L1(t+1) 5.8083 | L2(t+2) 6.7518 | sum 12.5601 | gap(L2-L1) +0.9435
# step  775/4000 | L1(t+1) 5.8344 | L2(t+2) 6.7777 | sum 12.6120 | gap(L2-L1) +0.9433
# step  800/4000 | L1(t+1) 5.8841 | L2(t+2) 6.8026 | sum 12.6867 | gap(L2-L1) +0.9185
# step  825/4000 | L1(t+1) 6.0021 | L2(t+2) 6.9211 | sum 12.9233 | gap(L2-L1) +0.9190
# step  850/4000 | L1(t+1) 5.7433 | L2(t+2) 6.7066 | sum 12.4498 | gap(L2-L1) +0.9633
# step  875/4000 | L1(t+1) 5.6654 | L2(t+2) 6.6110 | sum 12.2764 | gap(L2-L1) +0.9457
# step  900/4000 | L1(t+1) 5.6527 | L2(t+2) 6.6428 | sum 12.2955 | gap(L2-L1) +0.9901
# step  925/4000 | L1(t+1) 5.7122 | L2(t+2) 6.6755 | sum 12.3877 | gap(L2-L1) +0.9633
# step  950/4000 | L1(t+1) 5.6453 | L2(t+2) 6.6372 | sum 12.2825 | gap(L2-L1) +0.9919
# step  975/4000 | L1(t+1) 5.7139 | L2(t+2) 6.6827 | sum 12.3967 | gap(L2-L1) +0.9688
# step 1000/4000 | L1(t+1) 5.5649 | L2(t+2) 6.5630 | sum 12.1279 | gap(L2-L1) +0.9981
# step 1025/4000 | L1(t+1) 5.5113 | L2(t+2) 6.5117 | sum 12.0229 | gap(L2-L1) +1.0004
# step 1050/4000 | L1(t+1) 5.6313 | L2(t+2) 6.6014 | sum 12.2327 | gap(L2-L1) +0.9700
# step 1075/4000 | L1(t+1) 5.4953 | L2(t+2) 6.4588 | sum 11.9542 | gap(L2-L1) +0.9635
# step 1100/4000 | L1(t+1) 5.4842 | L2(t+2) 6.4702 | sum 11.9544 | gap(L2-L1) +0.9861
# step 1125/4000 | L1(t+1) 5.4740 | L2(t+2) 6.4695 | sum 11.9434 | gap(L2-L1) +0.9955
# step 1150/4000 | L1(t+1) 5.3994 | L2(t+2) 6.4244 | sum 11.8238 | gap(L2-L1) +1.0250
# step 1175/4000 | L1(t+1) 5.6512 | L2(t+2) 6.6732 | sum 12.3244 | gap(L2-L1) +1.0220
# step 1200/4000 | L1(t+1) 5.6006 | L2(t+2) 6.6552 | sum 12.2558 | gap(L2-L1) +1.0545
# step 1225/4000 | L1(t+1) 5.4674 | L2(t+2) 6.4943 | sum 11.9617 | gap(L2-L1) +1.0269
# step 1250/4000 | L1(t+1) 5.5148 | L2(t+2) 6.5359 | sum 12.0507 | gap(L2-L1) +1.0210
# step 1275/4000 | L1(t+1) 5.4651 | L2(t+2) 6.5252 | sum 11.9903 | gap(L2-L1) +1.0601
# step 1300/4000 | L1(t+1) 5.4460 | L2(t+2) 6.4985 | sum 11.9445 | gap(L2-L1) +1.0526
# step 1325/4000 | L1(t+1) 5.3252 | L2(t+2) 6.3950 | sum 11.7201 | gap(L2-L1) +1.0698
# step 1350/4000 | L1(t+1) 5.1995 | L2(t+2) 6.2756 | sum 11.4752 | gap(L2-L1) +1.0761
# step 1375/4000 | L1(t+1) 5.3317 | L2(t+2) 6.3802 | sum 11.7119 | gap(L2-L1) +1.0485
# step 1400/4000 | L1(t+1) 5.2964 | L2(t+2) 6.3355 | sum 11.6319 | gap(L2-L1) +1.0391
# step 1425/4000 | L1(t+1) 5.2419 | L2(t+2) 6.3027 | sum 11.5447 | gap(L2-L1) +1.0608
# step 1450/4000 | L1(t+1) 5.3494 | L2(t+2) 6.4498 | sum 11.7992 | gap(L2-L1) +1.1004
# step 1475/4000 | L1(t+1) 5.3660 | L2(t+2) 6.4128 | sum 11.7788 | gap(L2-L1) +1.0467
# step 1500/4000 | L1(t+1) 5.2213 | L2(t+2) 6.3054 | sum 11.5267 | gap(L2-L1) +1.0841
# step 1525/4000 | L1(t+1) 5.3434 | L2(t+2) 6.4366 | sum 11.7800 | gap(L2-L1) +1.0932
# step 1550/4000 | L1(t+1) 5.2002 | L2(t+2) 6.2818 | sum 11.4819 | gap(L2-L1) +1.0816
# step 1575/4000 | L1(t+1) 5.3041 | L2(t+2) 6.4157 | sum 11.7198 | gap(L2-L1) +1.1116
# step 1600/4000 | L1(t+1) 5.1536 | L2(t+2) 6.2661 | sum 11.4197 | gap(L2-L1) +1.1126
# step 1625/4000 | L1(t+1) 5.0891 | L2(t+2) 6.2366 | sum 11.3258 | gap(L2-L1) +1.1475
# step 1650/4000 | L1(t+1) 5.2502 | L2(t+2) 6.3520 | sum 11.6022 | gap(L2-L1) +1.1018
# step 1675/4000 | L1(t+1) 5.0389 | L2(t+2) 6.1559 | sum 11.1948 | gap(L2-L1) +1.1170
# step 1700/4000 | L1(t+1) 5.1924 | L2(t+2) 6.2926 | sum 11.4850 | gap(L2-L1) +1.1002
# step 1725/4000 | L1(t+1) 4.9964 | L2(t+2) 6.0932 | sum 11.0897 | gap(L2-L1) +1.0968
# step 1750/4000 | L1(t+1) 5.2022 | L2(t+2) 6.3389 | sum 11.5411 | gap(L2-L1) +1.1367
# step 1775/4000 | L1(t+1) 5.2990 | L2(t+2) 6.3745 | sum 11.6735 | gap(L2-L1) +1.0756
# step 1800/4000 | L1(t+1) 5.1932 | L2(t+2) 6.2998 | sum 11.4930 | gap(L2-L1) +1.1065
# step 1825/4000 | L1(t+1) 4.9877 | L2(t+2) 6.1070 | sum 11.0946 | gap(L2-L1) +1.1193
# step 1850/4000 | L1(t+1) 4.9319 | L2(t+2) 6.0747 | sum 11.0066 | gap(L2-L1) +1.1428
# step 1875/4000 | L1(t+1) 5.0640 | L2(t+2) 6.2214 | sum 11.2854 | gap(L2-L1) +1.1573
# step 1900/4000 | L1(t+1) 5.1205 | L2(t+2) 6.2562 | sum 11.3767 | gap(L2-L1) +1.1357
# step 1925/4000 | L1(t+1) 5.0501 | L2(t+2) 6.1947 | sum 11.2448 | gap(L2-L1) +1.1447
# step 1950/4000 | L1(t+1) 5.0909 | L2(t+2) 6.2580 | sum 11.3489 | gap(L2-L1) +1.1671
# step 1975/4000 | L1(t+1) 4.9195 | L2(t+2) 6.1064 | sum 11.0260 | gap(L2-L1) +1.1869
# step 2000/4000 | L1(t+1) 5.1573 | L2(t+2) 6.2996 | sum 11.4569 | gap(L2-L1) +1.1422
# step 2025/4000 | L1(t+1) 5.0099 | L2(t+2) 6.1573 | sum 11.1672 | gap(L2-L1) +1.1475
# step 2050/4000 | L1(t+1) 5.0294 | L2(t+2) 6.1472 | sum 11.1766 | gap(L2-L1) +1.1178
# step 2075/4000 | L1(t+1) 4.9451 | L2(t+2) 6.0888 | sum 11.0339 | gap(L2-L1) +1.1437
# step 2100/4000 | L1(t+1) 5.1253 | L2(t+2) 6.2676 | sum 11.3929 | gap(L2-L1) +1.1423
# step 2125/4000 | L1(t+1) 5.0267 | L2(t+2) 6.1878 | sum 11.2145 | gap(L2-L1) +1.1611
# step 2150/4000 | L1(t+1) 4.9569 | L2(t+2) 6.1051 | sum 11.0620 | gap(L2-L1) +1.1483
# step 2175/4000 | L1(t+1) 4.9652 | L2(t+2) 6.0719 | sum 11.0371 | gap(L2-L1) +1.1068
# step 2200/4000 | L1(t+1) 5.1012 | L2(t+2) 6.2733 | sum 11.3745 | gap(L2-L1) +1.1720
# step 2225/4000 | L1(t+1) 5.0020 | L2(t+2) 6.1835 | sum 11.1856 | gap(L2-L1) +1.1815
# step 2250/4000 | L1(t+1) 4.7761 | L2(t+2) 5.9675 | sum 10.7437 | gap(L2-L1) +1.1914
# step 2275/4000 | L1(t+1) 4.8408 | L2(t+2) 6.0265 | sum 10.8673 | gap(L2-L1) +1.1856
# step 2300/4000 | L1(t+1) 4.9076 | L2(t+2) 6.0876 | sum 10.9952 | gap(L2-L1) +1.1800
# step 2325/4000 | L1(t+1) 4.6161 | L2(t+2) 5.7680 | sum 10.3842 | gap(L2-L1) +1.1519
# step 2350/4000 | L1(t+1) 4.8466 | L2(t+2) 6.0281 | sum 10.8747 | gap(L2-L1) +1.1816
# step 2375/4000 | L1(t+1) 5.0217 | L2(t+2) 6.1890 | sum 11.2108 | gap(L2-L1) +1.1673
# step 2400/4000 | L1(t+1) 4.7717 | L2(t+2) 5.9410 | sum 10.7127 | gap(L2-L1) +1.1693
# step 2425/4000 | L1(t+1) 4.7925 | L2(t+2) 6.0076 | sum 10.8001 | gap(L2-L1) +1.2151
# step 2450/4000 | L1(t+1) 4.9220 | L2(t+2) 6.1030 | sum 11.0250 | gap(L2-L1) +1.1811
# step 2475/4000 | L1(t+1) 4.9356 | L2(t+2) 6.1729 | sum 11.1085 | gap(L2-L1) +1.2373
# step 2500/4000 | L1(t+1) 4.9314 | L2(t+2) 6.1182 | sum 11.0496 | gap(L2-L1) +1.1868
# step 2525/4000 | L1(t+1) 4.9386 | L2(t+2) 6.1355 | sum 11.0741 | gap(L2-L1) +1.1969
# step 2550/4000 | L1(t+1) 4.9083 | L2(t+2) 6.0952 | sum 11.0035 | gap(L2-L1) +1.1869
# step 2575/4000 | L1(t+1) 4.9834 | L2(t+2) 6.1821 | sum 11.1655 | gap(L2-L1) +1.1987
# step 2600/4000 | L1(t+1) 4.8342 | L2(t+2) 6.0112 | sum 10.8455 | gap(L2-L1) +1.1770
# step 2625/4000 | L1(t+1) 4.9393 | L2(t+2) 6.1584 | sum 11.0977 | gap(L2-L1) +1.2191
# step 2650/4000 | L1(t+1) 4.7550 | L2(t+2) 6.0206 | sum 10.7756 | gap(L2-L1) +1.2656
# step 2675/4000 | L1(t+1) 4.9199 | L2(t+2) 6.1235 | sum 11.0433 | gap(L2-L1) +1.2036
# step 2700/4000 | L1(t+1) 4.6121 | L2(t+2) 5.8568 | sum 10.4689 | gap(L2-L1) +1.2448
# step 2725/4000 | L1(t+1) 4.8228 | L2(t+2) 5.9804 | sum 10.8033 | gap(L2-L1) +1.1576
# step 2750/4000 | L1(t+1) 4.9423 | L2(t+2) 6.1487 | sum 11.0910 | gap(L2-L1) +1.2065
# step 2775/4000 | L1(t+1) 4.7765 | L2(t+2) 6.0231 | sum 10.7995 | gap(L2-L1) +1.2466
# step 2800/4000 | L1(t+1) 4.8788 | L2(t+2) 6.1043 | sum 10.9831 | gap(L2-L1) +1.2255
# step 2825/4000 | L1(t+1) 4.7371 | L2(t+2) 5.9320 | sum 10.6690 | gap(L2-L1) +1.1949
# step 2850/4000 | L1(t+1) 4.7172 | L2(t+2) 5.9365 | sum 10.6537 | gap(L2-L1) +1.2194
# step 2875/4000 | L1(t+1) 4.6567 | L2(t+2) 5.8590 | sum 10.5157 | gap(L2-L1) +1.2024
# step 2900/4000 | L1(t+1) 4.7416 | L2(t+2) 5.9472 | sum 10.6888 | gap(L2-L1) +1.2056
# step 2925/4000 | L1(t+1) 4.7179 | L2(t+2) 5.9545 | sum 10.6723 | gap(L2-L1) +1.2366
# step 2950/4000 | L1(t+1) 4.7129 | L2(t+2) 5.9398 | sum 10.6527 | gap(L2-L1) +1.2269
# step 2975/4000 | L1(t+1) 4.6965 | L2(t+2) 5.9254 | sum 10.6219 | gap(L2-L1) +1.2290
# step 3000/4000 | L1(t+1) 4.5489 | L2(t+2) 5.7851 | sum 10.3340 | gap(L2-L1) +1.2363
# step 3025/4000 | L1(t+1) 4.7110 | L2(t+2) 5.9595 | sum 10.6705 | gap(L2-L1) +1.2485
# step 3050/4000 | L1(t+1) 4.8583 | L2(t+2) 6.0638 | sum 10.9221 | gap(L2-L1) +1.2054
# step 3075/4000 | L1(t+1) 4.6982 | L2(t+2) 5.9190 | sum 10.6172 | gap(L2-L1) +1.2208
# step 3100/4000 | L1(t+1) 4.8042 | L2(t+2) 5.9942 | sum 10.7983 | gap(L2-L1) +1.1900
# step 3125/4000 | L1(t+1) 4.6422 | L2(t+2) 5.8666 | sum 10.5089 | gap(L2-L1) +1.2244
# step 3150/4000 | L1(t+1) 4.7567 | L2(t+2) 6.0028 | sum 10.7595 | gap(L2-L1) +1.2461
# step 3175/4000 | L1(t+1) 4.6437 | L2(t+2) 5.8857 | sum 10.5295 | gap(L2-L1) +1.2420
# step 3200/4000 | L1(t+1) 4.6881 | L2(t+2) 5.9106 | sum 10.5987 | gap(L2-L1) +1.2225
# step 3225/4000 | L1(t+1) 4.6731 | L2(t+2) 5.8818 | sum 10.5549 | gap(L2-L1) +1.2086
# step 3250/4000 | L1(t+1) 4.5849 | L2(t+2) 5.8166 | sum 10.4015 | gap(L2-L1) +1.2317
# step 3275/4000 | L1(t+1) 4.7139 | L2(t+2) 5.9981 | sum 10.7120 | gap(L2-L1) +1.2842
# step 3300/4000 | L1(t+1) 4.6593 | L2(t+2) 5.8990 | sum 10.5584 | gap(L2-L1) +1.2397
# step 3325/4000 | L1(t+1) 4.7153 | L2(t+2) 5.9183 | sum 10.6335 | gap(L2-L1) +1.2030
# step 3350/4000 | L1(t+1) 4.7351 | L2(t+2) 5.9806 | sum 10.7157 | gap(L2-L1) +1.2456
# step 3375/4000 | L1(t+1) 4.7206 | L2(t+2) 5.9564 | sum 10.6770 | gap(L2-L1) +1.2357
# step 3400/4000 | L1(t+1) 4.5017 | L2(t+2) 5.7259 | sum 10.2275 | gap(L2-L1) +1.2242
# step 3425/4000 | L1(t+1) 4.7916 | L2(t+2) 5.9745 | sum 10.7661 | gap(L2-L1) +1.1830
# step 3450/4000 | L1(t+1) 4.4576 | L2(t+2) 5.6765 | sum 10.1341 | gap(L2-L1) +1.2190
# step 3475/4000 | L1(t+1) 4.5753 | L2(t+2) 5.8128 | sum 10.3881 | gap(L2-L1) +1.2375
# step 3500/4000 | L1(t+1) 4.6427 | L2(t+2) 5.8905 | sum 10.5331 | gap(L2-L1) +1.2478
# step 3525/4000 | L1(t+1) 4.7564 | L2(t+2) 6.0296 | sum 10.7860 | gap(L2-L1) +1.2732
# step 3550/4000 | L1(t+1) 4.5558 | L2(t+2) 5.7541 | sum 10.3099 | gap(L2-L1) +1.1984
# step 3575/4000 | L1(t+1) 4.5731 | L2(t+2) 5.7921 | sum 10.3652 | gap(L2-L1) +1.2190
# step 3600/4000 | L1(t+1) 4.6235 | L2(t+2) 5.8398 | sum 10.4633 | gap(L2-L1) +1.2163
# step 3625/4000 | L1(t+1) 4.7307 | L2(t+2) 5.9720 | sum 10.7027 | gap(L2-L1) +1.2413
# step 3650/4000 | L1(t+1) 4.6003 | L2(t+2) 5.8389 | sum 10.4392 | gap(L2-L1) +1.2386
# step 3675/4000 | L1(t+1) 4.5950 | L2(t+2) 5.8521 | sum 10.4471 | gap(L2-L1) +1.2571
# step 3700/4000 | L1(t+1) 4.7249 | L2(t+2) 5.9596 | sum 10.6845 | gap(L2-L1) +1.2346
# step 3725/4000 | L1(t+1) 4.5159 | L2(t+2) 5.8595 | sum 10.3754 | gap(L2-L1) +1.3437
# step 3750/4000 | L1(t+1) 4.6250 | L2(t+2) 5.8903 | sum 10.5153 | gap(L2-L1) +1.2653
# step 3775/4000 | L1(t+1) 4.5878 | L2(t+2) 5.8420 | sum 10.4297 | gap(L2-L1) +1.2542
# step 3800/4000 | L1(t+1) 4.7422 | L2(t+2) 6.0208 | sum 10.7629 | gap(L2-L1) +1.2786
# step 3825/4000 | L1(t+1) 4.5788 | L2(t+2) 5.8420 | sum 10.4208 | gap(L2-L1) +1.2632
# step 3850/4000 | L1(t+1) 4.5096 | L2(t+2) 5.8033 | sum 10.3129 | gap(L2-L1) +1.2937
# step 3875/4000 | L1(t+1) 4.6375 | L2(t+2) 5.9134 | sum 10.5509 | gap(L2-L1) +1.2759
# step 3900/4000 | L1(t+1) 4.6687 | L2(t+2) 5.9220 | sum 10.5907 | gap(L2-L1) +1.2534
# step 3925/4000 | L1(t+1) 4.6087 | L2(t+2) 5.8759 | sum 10.4846 | gap(L2-L1) +1.2671
# step 3950/4000 | L1(t+1) 4.4194 | L2(t+2) 5.6628 | sum 10.0822 | gap(L2-L1) +1.2434
# step 3975/4000 | L1(t+1) 4.6724 | L2(t+2) 5.9265 | sum 10.5989 | gap(L2-L1) +1.2540
# step 3999/4000 | L1(t+1) 4.7250 | L2(t+2) 5.9942 | sum 10.7192 | gap(L2-L1) +1.2692
#
# MTP training done in 957.6s

# %%
fig, ax = plt.subplots(figsize=(9, 5))
ax.plot(loss1_hist, color=COLORS["head1"], linewidth=2, label="Head 1: predicts t+1")
ax.plot(loss2_hist, color=COLORS["head2"], linewidth=2, label="Head 2: predicts t+2")
ax.plot(
    sum_hist,
    color=COLORS["sum"],
    linewidth=1.5,
    linestyle="--",
    label="Sum (L1 + L2, the optimized objective)",
)
ax.set_xlabel("training step")
ax.set_ylabel("loss (nats)")
ax.set_title("Multi-token prediction: t+1 vs. t+2 head losses over training")
ax.legend(frameon=False)
plt.tight_layout()
plt.savefig("assets/mtp_losses.png", dpi=130)
plt.show()

# %% [markdown]
# ### 6.1 What Happens to the Second Head's Loss
#
# Both heads share the same trunk, so anything that improves the shared hidden state
# helps both objectives at once — which is why the two curves fall *together* rather
# than independently. But predicting `t+2` is a strictly harder target than `t+1`: it
# has to survive one additional step of genuine uncertainty about what the text does
# next, so its irreducible entropy floor is higher than `t+1`'s even for a perfect
# model. At step 0 both heads are random, so the gap is ~0 and pure noise; the
# expectation is that as training shapes the trunk, `L2` settles **above** `L1` and
# stays there.
#
# Per-step training loss is one random minibatch — noisy by ±0.1–0.2 nats. So the
# cell below reads every "settled" number off a **trailing-window mean**, never the
# last data point, and it reports that window's noise so small differences can be
# judged against it: the `t+2` gap is many times the noise; the cost of the second
# head to the `t+1` objective is comparable to it.

# %%
a1, a2, asum = np.array(loss1_hist), np.array(loss2_hist), np.array(sum_hist)
abase = np.array(baseline_losses)
start_gap = a2[0] - a1[0]
end_gap = a2[-1] - a1[-1]

# Per-step training loss is noisy (each step is one random minibatch). Read the
# SETTLED values off a trailing window, not the last data point.
W = max(50, N_STEPS // 10)
w1, w2, wsum, wbase = a1[-W:], a2[-W:], asum[-W:], abase[-W:]
noise = float(np.std(w1))  # ~ per-step loss noise amplitude in nats

print(f"trailing window for 'settled' values : last {W} steps")
print(
    f"                        step 0     ->  final step   ->  last-{W} mean  (sd {noise:.3f})"
)
print(
    f"Head 1 (t+1)  : {a1[0]:8.4f}  ->  {a1[-1]:8.4f}  ->  {w1.mean():8.4f}   (ppl {perplexity(float(w1.mean())):.1f})"
)
print(
    f"Head 2 (t+2)  : {a2[0]:8.4f}  ->  {a2[-1]:8.4f}  ->  {w2.mean():8.4f}   (ppl {perplexity(float(w2.mean())):.1f})"
)
print(f"Sum (opt.)    : {asum[0]:8.4f}  ->  {asum[-1]:8.4f}  ->  {wsum.mean():8.4f}")
print(
    f"baseline solo : {abase[0]:8.4f}  ->  {abase[-1]:8.4f}  ->  {wbase.mean():8.4f}   (ppl {perplexity(float(wbase.mean())):.1f})"
)

gaps = a2 - a1
frac_above = float((gaps > 0).mean())
tail = gaps[max(1, len(gaps) // 10) :]  # drop the random-init transient
gap_settled = float((w2 - w1).mean())
h1_minus_base = float(w1.mean() - wbase.mean())
sem = noise / (W**0.5)  # standard error of a trailing-window mean

print(
    f"\ngap (L2 - L1)  : start {start_gap:+.4f}  final {end_gap:+.4f}  "
    f"last-{W} mean {gap_settled:+.4f}   ({frac_above * 100:.0f}% of all steps have L2 > L1)"
)
print(
    f"  -> trailing-mean gap is {gap_settled / sem:+.1f} standard errors from zero "
    f"(SE of the {W}-step mean = {sem:.4f})"
)
print(f"\nMTP head1 vs standalone baseline (last-{W} mean) : {h1_minus_base:+.4f} nats")
print(
    f"  per-step noise sd {noise:.3f}  |  std error of the {W}-step mean {sem:.4f}  "
    f"->  {abs(h1_minus_base) / sem:.1f} SE"
)
print("  -> a small, consistently-positive cost: far below the +-0.2 nat swing of any")
print("     single step, but cleanly resolved in the trailing mean. And the comparison")
print(
    "     is unfair to the two-head model: its t+1 head is UNTIED and also carries the"
)
print("     t+2 gradient, while the baseline's is TIED (tying usually helps a little).")

verdict = (
    "as expected: t+2 is the harder target"
    if gap_settled > 5 * sem
    else "gap is within trailing-mean noise -- inspect (too few steps? lr? scale?)"
)
print(f"\n==> {verdict}")

RESULTS["mtp"] = {
    "steps": N_STEPS,
    "trailing_window": int(W),
    "per_step_noise_nats": noise,
    "trailing_mean_sem_nats": sem,
    "head1_loss_start": float(a1[0]),
    "head1_loss_end": float(a1[-1]),
    "head1_loss_settled": float(w1.mean()),
    "head2_loss_start": float(a2[0]),
    "head2_loss_end": float(a2[-1]),
    "head2_loss_settled": float(w2.mean()),
    "sum_start": float(asum[0]),
    "sum_end": float(asum[-1]),
    "sum_settled": float(wsum.mean()),
    "baseline_loss_end": float(abase[-1]),
    "baseline_loss_settled": float(wbase.mean()),
    "gap_start": float(start_gap),
    "gap_end": float(end_gap),
    "gap_settled": gap_settled,
    "gap_mean": float(gaps.mean()),
    "gap_mean_after_warmup": float(tail.mean()),
    "frac_steps_L2_above_L1": frac_above,
    "head1_minus_baseline_settled": h1_minus_base,
}
# Out:
# trailing window for 'settled' values : last 400 steps
#                         step 0     ->  final step   ->  last-400 mean  (sd 0.109)
# Head 1 (t+1)  :  10.8917  ->    4.7250  ->    4.6020   (ppl 99.7)
# Head 2 (t+2)  :  10.9536  ->    5.9942  ->    5.8654   (ppl 352.6)
# Sum (opt.)    :  21.8453  ->   10.7192  ->   10.4674
# baseline solo :  10.9386  ->    4.6533  ->    4.5552   (ppl 95.1)
#
# gap (L2 - L1)  : start +0.0618  final +1.2692  last-400 mean +1.2634   (100% of all steps have L2 > L1)
#   -> trailing-mean gap is +231.0 standard errors from zero (SE of the 400-step mean = 0.0055)
#
# MTP head1 vs standalone baseline (last-400 mean) : +0.0469 nats
#   per-step noise sd 0.109  |  std error of the 400-step mean 0.0055  ->  8.6 SE
#   -> a small, consistently-positive cost: far below the +-0.2 nat swing of any
#      single step, but cleanly resolved in the trailing mean. And the comparison
#      is unfair to the two-head model: its t+1 head is UNTIED and also carries the
#      t+2 gradient, while the baseline's is TIED (tying usually helps a little).
#
# ==> as expected: t+2 is the harder target

# %% [markdown]
# ### 6.2 Boundary Masking, Re-checked on the Trained Model
#
# Section 3.4 ran the packed-document boundary check on an *untrained* head, where the
# before/after difference was tiny — every position scored near `ln V` regardless. Now
# that the `t+1` head has trained for the full run, the same check should bite: the
# model is good at real continuations, so the boundary position (predicting the first
# token of an unrelated document) is a genuine, high-loss failure that drags the mean
# up. The exact same two packed documents from 3.4 are re-scored below.

# %%
bd = BOUNDARY_DEMO
mtp_model.eval()
head_t1.eval()
with torch.no_grad():
    hb = mtp_model(bd["inputs"])
    zb = head_t1(hb)
    ptl = F.cross_entropy(
        zb.reshape(-1, VOCAB_SIZE), bd["targets"].reshape(-1), reduction="none"
    )
mtp_model.train()
head_t1.train()

bi = bd["boundary_idx"]
tr_before = ptl.mean().item()
tr_boundary = ptl[bi].item()
tr_after = (ptl.sum().item() - tr_boundary) / (ptl.numel() - 1)
mean_other = (ptl.sum().item() - tr_boundary) / (ptl.numel() - 1)

u = RESULTS["boundary"]  # the untrained numbers from 3.4
print(f"{'':22s}{'UNTRAINED (3.4)':>18s}{'TRAINED (here)':>18s}")
print(f"{'mean loss, all pos':22s}{u['loss_before']:>18.4f}{tr_before:>18.4f}")
print(f"{'mean loss, boundary masked':22s}{u['loss_after']:>18.4f}{tr_after:>18.4f}")
print(
    f"{'boundary position itself':22s}{u['boundary_loss']:>18.4f}{tr_boundary:>18.4f}"
)
print(
    f"{'delta from masking':22s}{u['loss_after'] - u['loss_before']:>+18.4f}{tr_after - tr_before:>+18.4f}"
)
print()
print(
    f"boundary loss / mean-of-the-rest : untrained {u['boundary_loss'] / u['loss_after']:.2f}x   "
    f"trained {tr_boundary / mean_other:.2f}x"
)
print("On the trained head the boundary position is the worst position in the sequence")
print("by a wide margin -- exactly the spurious 'unrelated things follow each other'")
print("signal a loss mask at the join removes. Untrained, it was indistinguishable.")

RESULTS["boundary"]["trained"] = {
    "loss_before": tr_before,
    "loss_after": tr_after,
    "boundary_loss": tr_boundary,
    "delta": tr_after - tr_before,
}
# Out:
#                          UNTRAINED (3.4)    TRAINED (here)
# mean loss, all pos               10.7940            5.6512
# mean loss, boundary masked           10.7902            5.4732
# boundary position itself           10.9666           13.8385
# delta from masking               -0.0038           -0.1780
#
# boundary loss / mean-of-the-rest : untrained 1.02x   trained 2.53x
# On the trained head the boundary position is the worst position in the sequence
# by a wide margin -- exactly the spurious 'unrelated things follow each other'
# signal a loss mask at the join removes. Untrained, it was indistinguishable.

# %% [markdown]
# ## 7. Inspecting the Aim Run
#
# The run is closed, and the on-disk `.aim` repo is checked directly to confirm
# everything was actually written to the tracking store (rather than just trusting
# that `.track()` calls silently succeeded).

# %%
run_hash = aim_run.hash
aim_run.close()

repo_check = Repo(".")
all_hashes = list(repo_check._all_run_hashes())
print(f"Aim repo path         : {os.path.abspath('.aim')}")
print(f"this run's hash        : {run_hash}")
print(f"runs found in the repo  : {len(all_hashes)} -> {all_hashes}")
print(f"this run is present     : {run_hash in all_hashes}")

print("\nTo explore interactively:")
print("  cd session9 && uv run aim up")
print("  then open http://localhost:43800")
# Out:
# Aim repo path         : /home/ravi.naik/learning/era/ERA/v5/session9/loss_harness/.aim
# this run's hash        : 40951568012744718a1101ab
# runs found in the repo  : 1 -> ['40951568012744718a1101ab']
# this run is present     : True
#
# To explore interactively:
#   cd session9 && uv run aim up
#   then open http://localhost:43800

# %% [markdown]
# ## 8. Final Summary — The Seven Numbers (Part 1) + Two Losses (Part 2)
#
# One row per Part 1 checklist item, plus the Part 2 head comparison. Also written to
# `assets/results.json` so the README can quote the exact same numbers this run
# produced.

# %%
seven_numbers = [
    (
        "1. Tensor shapes",
        f"tokens {RESULTS['shapes']['tokens']}, hidden {RESULTS['shapes']['hidden']}, "
        f"logits {RESULTS['shapes']['logits']}",
    ),
    (
        "2. Shift verification",
        f"{RESULTS['shift_mismatches']}/12 target-slice mismatches "
        f"(0 = targets_out is the correct slice; loss-call alignment is checked by #5)",
    ),
    (
        "3. Padding mask: contributing tokens",
        f"{RESULTS['padding']['contributing_before']} -> "
        f"{RESULTS['padding']['contributing_after']} "
        f"(loss {RESULTS['padding']['loss_before']:.4f} -> {RESULTS['padding']['loss_after']:.4f})",
    ),
    (
        "4. Boundary mask: loss before/after",
        (
            f"untrained {RESULTS['boundary']['loss_before']:.4f} -> {RESULTS['boundary']['loss_after']:.4f} "
            f"(delta {RESULTS['boundary']['loss_after'] - RESULTS['boundary']['loss_before']:+.4f}); "
            + (
                f"TRAINED {RESULTS['boundary']['trained']['loss_before']:.4f} -> {RESULTS['boundary']['trained']['loss_after']:.4f} "
                f"(delta {RESULTS['boundary']['trained']['delta']:+.4f}, boundary pos itself "
                f"{RESULTS['boundary']['trained']['boundary_loss']:.4f})"
                if RESULTS["boundary"].get("trained")
                else "trained re-check: see 6.2"
            )
        ),
    ),
    (
        "5. Perplexity anchor (nats)",
        f"untrained loss {RESULTS['perplexity']['loss_untrained']:.4f} vs. ln V "
        f"{RESULTS['perplexity']['ln_v']:.4f}  (gap {RESULTS['perplexity']['relative_gap_pct']:.2f}% in nats; "
        f"ppl {RESULTS['perplexity']['ppl_untrained']:,.0f} vs. V {RESULTS['perplexity']['vocab_size']:,})",
    ),
    (
        "6. Tied vs. untied head params",
        f"{RESULTS['tied_vs_untied']['total_tied']:,} vs. "
        f"{RESULTS['tied_vs_untied']['total_untied']:,} "
        f"({RESULTS['tied_vs_untied']['ratio']:.3f}x)",
    ),
    (
        "7. Peak memory: ordinary vs. chunked",
        (
            f"{human_bytes(RESULTS['memory']['peak_ordinary_bytes'])} vs. "
            f"{human_bytes(RESULTS['memory']['peak_chunked_bytes'])} "
            f"({RESULTS['memory']['ratio']:.1f}x)  [predicted {RESULTS['memory']['predicted_ordinary_gib']} / "
            f"{RESULTS['memory']['predicted_chunked_gib']} GiB]"
        )
        if RESULTS["memory"]["ratio"]
        else (
            f"CPU: no counter -- predicted {RESULTS['memory']['predicted_ordinary_gib']} GiB vs. "
            f"{RESULTS['memory']['predicted_chunked_gib']} GiB "
            f"(~{RESULTS['memory']['predicted_ordinary_gib'] / max(RESULTS['memory']['predicted_chunked_gib'], 1e-9):.0f}x)"
        ),
    ),
]

df = pd.DataFrame(seven_numbers, columns=["Checklist item", "Result"])
print("=" * 100)
print("PART 1 -- THE SEVEN NUMBERS")
print("=" * 100)
for _, row in df.iterrows():
    print(f"{row['Checklist item']:<42} {row['Result']}")

print()
print("=" * 100)
print(
    "PART 2 -- THE TWO LOSSES  (settled = last-{} steps, trailing mean)".format(
        RESULTS["mtp"]["trailing_window"]
    )
)
print("=" * 100)
m = RESULTS["mtp"]
print(
    f"Head 1 (t+1) : final {m['head1_loss_end']:.4f}   settled {m['head1_loss_settled']:.4f} nats"
)
print(
    f"Head 2 (t+2) : final {m['head2_loss_end']:.4f}   settled {m['head2_loss_settled']:.4f} nats"
)
print(f"Sum (opt.)   : final {m['sum_end']:.4f}   settled {m['sum_settled']:.4f} nats")
print(
    f"gap (L2-L1)  : start {m['gap_start']:+.4f}  final {m['gap_end']:+.4f}  settled {m['gap_settled']:+.4f}  "
    f"({m['frac_steps_L2_above_L1'] * 100:.0f}% of steps L2>L1)"
)
print(
    f"MTP head1 - standalone baseline (settled) : {m['head1_minus_baseline_settled']:+.4f} nats "
    f"(per-step noise {m['per_step_noise_nats']:.3f})"
)

RESULTS["smoke"] = SMOKE
RESULTS["config"] = {
    "dataset": DATASET_CONFIG,
    "d_model": cfg.d_model,
    "n_layers": cfg.n_layers,
    "n_heads": cfg.n_heads,
    "seq_len": SEQ_LEN,
    "batch_size": BATCH_SIZE,
    "n_steps": N_STEPS,
}
with open("assets/results.json", "w") as f:
    json.dump(RESULTS, f, indent=2, default=str)
print("\nWrote assets/results.json")
if SMOKE:
    print(
        "\n*** SMOKE RUN — these numbers are from the tiny CPU config, not the real run. ***"
    )
    print(
        "*** Re-run with S9_SMOKE unset on a GPU server for the numbers to report.   ***"
    )
# Out:
# ====================================================================================================
# PART 1 -- THE SEVEN NUMBERS
# ====================================================================================================
# 1. Tensor shapes                           tokens [4, 32], hidden [4, 32, 512], logits [4, 32, 50257]
# 2. Shift verification                      0/12 target-slice mismatches (0 = targets_out is the correct slice; loss-call alignment is checked by #5)
# 3. Padding mask: contributing tokens       234 -> 167 (loss 10.6834 -> 10.8603)
# 4. Boundary mask: loss before/after        untrained 10.7940 -> 10.7902 (delta -0.0038); TRAINED 5.6512 -> 5.4732 (delta -0.1780, boundary pos itself 13.8385)
# 5. Perplexity anchor (nats)                untrained loss 10.9328 vs. ln V 10.8249  (gap 1.00% in nats; ppl 55,984 vs. V 50,257)
# 6. Tied vs. untied head params             51,692,544 vs. 77,424,128 (1.498x)
# 7. Peak memory: ordinary vs. chunked       10.61 GiB vs. 2.25 GiB (4.7x)  [predicted 12.43 / 0.93 GiB]
#
# ====================================================================================================
# PART 2 -- THE TWO LOSSES  (settled = last-400 steps, trailing mean)
# ====================================================================================================
# Head 1 (t+1) : final 4.7250   settled 4.6020 nats
# Head 2 (t+2) : final 5.9942   settled 5.8654 nats
# Sum (opt.)   : final 10.7192   settled 10.4674 nats
# gap (L2-L1)  : start +0.0618  final +1.2692  settled +1.2634  (100% of steps L2>L1)
# MTP head1 - standalone baseline (settled) : +0.0469 nats (per-step noise 0.109)
#
# Wrote assets/results.json

# %% [markdown]
# ## 9. Conclusion
#
# The harness now does what the assignment asked: every shape is printed and named;
# the shift is confirmed by reading real decoded strings, with the functional
# loss-call alignment left to the perplexity anchor; padding and document-boundary
# masking are shown to change the contributing-token count and the loss, and the
# boundary case is re-checked on the *trained* head where it actually bites; the
# untrained loss lands `1%` (in nats) from `ln V`; tied vs. untied head parameter
# counts are compared directly; and peak memory is measured for an ordinary vs. a
# hand-written chunked cross-entropy **with a byte-by-byte account** of the ~3×
# overhead the naive `[N, V]` figure misses (backward gradient, `float32` log-softmax
# up-cast) and the fixed floor that keeps the chunked path from reaching its
# one-chunk ideal. Part 2 adds a second, architecturally identical untied head
# predicting `t+2`: read off trailing-window means (single steps are ±0.1–0.2 nats of
# noise), its loss settles clearly above the `t+1` head's, while the `t+1` objective
# itself pays only a small, noise-scale cost for the extra head — and that comparison
# is if anything unfair to the two-head model, whose `t+1` head is untied where the
# baseline's is tied. All of it was tracked step-by-step in Aim, queryable
# independently of this notebook via `aim up`.
